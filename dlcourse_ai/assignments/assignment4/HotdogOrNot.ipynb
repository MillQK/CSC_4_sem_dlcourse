# %% [markdown]
# # Задание 4 - Перенос обучения (transfer learning) и тонкая настройка (fine-tuning)
#
# Одной из важнейшних техник в тренировке сетей - использовать заранее натренированные веса на более общей задачи в качестве начальной точки, а потом "дотренировать" их на конкретной.
#
# Такой подход и убыстряет обучение, и позволяет тренировать эффективные модели на маленьких наборах данных.
#
# В этом упражнении мы натренируем классификатор, который отличает хотдоги от не хотдогов!
# (более подробно - https://www.youtube.com/watch?v=ACmydtFDTGs)
#
# Это задание требует доступа к GPU, поэтому его можно выполнять либо на компьютере с GPU от NVidia, либо в [Google Colab](https://colab.research.google.com/).

# %%
import json
import os
import csv
import urllib
from io import BytesIO
from PIL import Image

from socket import timeout

from google.colab import files
#from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
#platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
#accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'
# !pip3 install -q torch torchvision
# !pip3 install -q Pillow==4.0.0

# %% [markdown]
# Сначала давайте скачаем данные с картинками. Это сделает код в следующей ячейке. Данные будут разделены на две части. На обучающей выборке, которая будет храниться в папке **train_kaggle**, мы будем строить наши модели, а на тестовой выборке **test_kaggle** будем предсказывать класс, к которому относится фотография (хотдог или нет).
#
# ### Если вы в Google Colab!
#
# В нем можно запускать ноутбуки с доступом к GPU. Они не очень быстрые, зато бесплатные!
# Каждый ноутбук получает свой собственный environment c доступным диском итд.
#
# Через 90 минут отсуствия активности этот environment пропадает со всеми данными.
# Поэтому нам придется скачивать данные каждый раз.

# %%
# Download train data
# !wget "https://www.dropbox.com/s/cupinvuotopehty/train.zip?dl=0"
# !unzip -q "train.zip?dl=0"

#local_folder = "../../HotDogOrNot/content/train_kaggle/"

train_folder = "train_kaggle/"
# Count number of files in the train folder, should be 4603
print('Number of files in the train folder', len(os.listdir(train_folder)))

# Download test data
# !wget "https://www.dropbox.com/s/7xakfl2r9gn5p1j/test.zip?dl=0"
# !unzip -q "test.zip?dl=0"

test_folder = "test_kaggle/"
# Count number of files in the test folder, should be 1150
print('Number of files in the test folder', len(os.listdir(test_folder)))
# Out:
# Number of files in the train folder 4603
# Number of files in the test folder 1150

# %%
# for local usage
train_folder = "train_kaggle/"
test_folder = "test_kaggle/"

# %%
import torch
from torchvision import models
from torch.utils.data import Dataset, SubsetRandomSampler
from torchvision import transforms

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

device = torch.device("cuda:0") # Let's make sure GPU is available!

# %% [markdown]
# # Имплементируем свой Dataset для загрузки данных
#
# В этом задании мы реализуем свой собственный класс Dataset для загрузки данных. Его цель - загрузить данные с диска и выдать по ним тензор с входом сети, меткой и идентификатором картинки (так будет проще подготовить сабмит для kaggle на тестовых данных).
#
# Вот ссылка, где хорошо объясняется как это делать на примере: https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
#
# Ваш Dataset должен в качестве количества сэмплов выдать количество файлов в папке и уметь выдавать кортеж из сэмпла, метки по индексу и названия файла.
# Если название файла начинается со слов 'frankfurter', 'chili-dog' или 'hotdog' - метка положительная. Иначе отрицательная (ноль).
#
# И не забудьте поддержать возможность трансформации входа (аргумент `transforms`), она нам понадобится!

# %%
class HotdogOrNotDataset(Dataset):
    def __init__(self, folder, transform=None):
        self.transform = transform
        self.folder = folder
        self.files = os.listdir(self.folder)
        
        # TODO: Your code here!
        
    def __len__(self):
        return len(self.files)
    
    def __getitem__(self, index):        
        # TODO Implement getting item by index
        # Hint: os.path.join is helpful!
        img_id = self.files[index]
        img_path = os.path.join(self.folder, img_id)
        img = Image.open(img_path)

        if self.transform:
            img = self.transform(img)
            
        label = 1 if (img_id.startswith("frankfurter") or img_id.startswith("chili-dog") or img_id.startswith("hotdog")) else 0
        
        return img, label, img_id

def visualize_samples(dataset, indices, title=None, count=10, image_titles=None):
    # visualize random 10 samples
    plt.figure(figsize=(count*3,3))
    display_indices = indices[:count]
    if title:
        plt.suptitle("%s %s/%s" % (title, len(display_indices), len(indices)))        
    for i, index in enumerate(display_indices): 
        x, y, img_id = dataset[index]
        plt.subplot(1,count,i+1)
        image_title = f"Label: {y}\nId: {img_id}"
        if image_titles:
            image_title += f"\n{image_titles[i]}"
        
        plt.title(image_title)
        plt.imshow(x)
        plt.grid(False)
        plt.axis('off')   
    
orig_dataset = HotdogOrNotDataset(train_folder)
indices = np.random.choice(np.arange(len(orig_dataset)), 7, replace=False)

visualize_samples(orig_dataset, indices, "Samples")

# %%
# Let's make sure transforms work!
dataset = HotdogOrNotDataset(train_folder, transform=transforms.RandomVerticalFlip(0.9))

visualize_samples(dataset, indices, "Samples with flip - a lot should be flipped!")

# %% [markdown]
# # Создаем Dataset для тренировки
#
# И разделяем его на train и validation.
# На train будем обучать модель, на validation проверять ее качество, а соревнование Kaggle In-Class проведем на фотографиях из папки test_kaggle.

# %%
# First, lets load the dataset
train_dataset = HotdogOrNotDataset(train_folder, 
                       transform=transforms.Compose([
                           transforms.Resize((224, 224)),
                           transforms.ToTensor(),
                           # Use mean and std for pretrained models
                           # https://pytorch.org/docs/stable/torchvision/models.html
                           transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])                         
                       ])
                      )
test_dataset = HotdogOrNotDataset(test_folder, 
                       transform=transforms.Compose([
                           transforms.Resize((224, 224)),
                           transforms.ToTensor(),
                           # Use mean and std for pretrained models
                           # https://pytorch.org/docs/stable/torchvision/models.html
                           transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])                         
                       ])
                      )

# %%
batch_size = 64

data_size = len(dataset)
validation_fraction = .2


val_split = int(np.floor((validation_fraction) * data_size))
indices = list(range(data_size))
np.random.seed(42)
np.random.shuffle(indices)

val_indices, train_indices = indices[:val_split], indices[val_split:]

train_sampler = SubsetRandomSampler(train_indices)
val_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, 
                                           sampler=train_sampler)
val_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
                                         sampler=val_sampler)
# Notice that we create test data loader in a different way. We don't have the labels.
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size)

# %% [markdown]
# Наши обычные функции для тренировки

# %%
def train_model(model, train_loader, val_loader, loss, optimizer, num_epochs, scheduler=None):    
    loss_history = []
    train_history = []
    val_history = []
    for epoch in range(num_epochs):
        model.train() # Enter train mode
        
        if scheduler:
            scheduler.step()
        
        loss_accum = 0
        correct_samples = 0
        total_samples = 0
        for i_step, (x, y,_) in enumerate(train_loader):
          
            x_gpu = x.to(device)
            y_gpu = y.to(device)
            prediction = model(x_gpu)    
            loss_value = loss(prediction, y_gpu)
            optimizer.zero_grad()
            loss_value.backward()
            optimizer.step()
            
            _, indices = torch.max(prediction, 1)
            correct_samples += torch.sum(indices == y_gpu)
            total_samples += y.shape[0]
            
            loss_accum += loss_value

        ave_loss = loss_accum / i_step
        train_accuracy = float(correct_samples) / total_samples
        val_accuracy = compute_accuracy(model, val_loader)
        
        loss_history.append(float(ave_loss))
        train_history.append(train_accuracy)
        val_history.append(val_accuracy)
        
        print("Average loss: %f, Train accuracy: %f, Val accuracy: %f" % (ave_loss, train_accuracy, val_accuracy))
        
    return loss_history, train_history, val_history
        
def compute_accuracy(model, loader):
    """
    Computes accuracy on the dataset wrapped in a loader
    
    Returns: accuracy as a float value between 0 and 1
    """
    model.eval() # Evaluation mode
    # TODO: Copy implementation from previous assignment
    # Don't forget to move the data to device before running it through the model!
        
    correct_samples = 0
    total_samples = 0
        
    for x, y, _ in loader:
      
        x_gpu = x.to(device)
        y_gpu = y.to(device)

        prediction = model(x_gpu)
        _, indices = torch.max(prediction, 1)
        correct_samples += torch.sum(indices == y_gpu)
        total_samples += y.shape[0]

    return 0.0 if not total_samples else float(correct_samples) / total_samples

# %% [markdown]
# # Использование заранее натренированной сети (pretrained network)
#
# Чаще всего в качестве заранее натренированной сети используется сеть, натренированная на данных ImageNet с 1M изображений и 1000 классами.
#
# PyTorch включает такие натренированные сети для различных архитектур (https://pytorch.org/docs/stable/torchvision/models.html)
# Мы будем использовать ResNet18.
#
# Для начала посмотрим, что выдает уже натренированная сеть на наших картинках. То есть, посмотрим к какому из 1000 классов их отнесет сеть.
#
# Запустите модель на 10 случайных картинках из датасета и выведите их вместе с классами с наибольшей вероятностью.
# В коде уже есть код, который формирует соответствие между индексами в выходном векторе и классами ImageNet.

# %%
# Thanks to https://discuss.pytorch.org/t/imagenet-classes/4923/2
def load_imagenet_classes():
    classes_json = urllib.request.urlopen('https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json').read()
    classes = json.loads(classes_json)
    
    # TODO: Process it to return dict of class index to name
    return { int(k): v[-1] for k, v in classes.items()}
    
model = models.resnet18(pretrained=True)
model.type(torch.cuda.FloatTensor)
model.to(device)
model.eval()

# TODO: Run this model on 10 random images of your dataset and visualize what it predicts
shuffled_indices = list(range(data_size))
np.random.seed(42)
np.random.shuffle(shuffled_indices)
shuffled_indices = shuffled_indices[:10]
random_ten_sampler = SubsetRandomSampler(shuffled_indices)
random_ten_loader = torch.utils.data.DataLoader(train_dataset, sampler=random_ten_sampler)

random_ten_predicted = []

for i, (x, y, _) in enumerate(random_ten_loader):

    x_gpu = x.to(device)
    y_gpu = y.to(device)

    prediction = model(x_gpu)
    _, indices = torch.max(prediction, 1)
    random_ten_predicted.extend(indices.cpu().numpy())

imagenet_classes = load_imagenet_classes()
random_ten_classes_names = [f"imagenet: {imagenet_classes[class_num]}" for class_num in random_ten_predicted]
visualize_data_set = HotdogOrNotDataset(train_folder)
visualize_samples(visualize_data_set, shuffled_indices, image_titles=random_ten_classes_names)

# %% [markdown]
# # Перенос обучения (transfer learning) - тренировать только последний слой
#
# Существует несколько вариантов переноса обучения, мы попробуем основные.
# Первый вариант - сделать новый последний слой и тренировать только его, заморозив остальные.

# %%
import torch.nn as nn
import torch.optim as optim

model = models.resnet18(pretrained=True)
# TODO: Freeze all the layers of this model and add a new output layer
# https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
for param in model.parameters():
    param.requires_grad = False

num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

model.type(torch.cuda.FloatTensor)
model.to(device)

parameters = model.fc.parameters()   # Fill the right thing here!

loss = nn.CrossEntropyLoss().type(torch.cuda.FloatTensor)
optimizer = optim.SGD(parameters, lr=0.001, momentum=0.9)
loss_history, train_history, val_history = train_model(model, train_loader, val_loader, loss, optimizer, 5)
# Out:
# Average loss: 0.348697, Train accuracy: 0.842248, Val accuracy: 0.932609
# Average loss: 0.205954, Train accuracy: 0.923975, Val accuracy: 0.938043
# Average loss: 0.178056, Train accuracy: 0.932664, Val accuracy: 0.944565
# Average loss: 0.172210, Train accuracy: 0.937279, Val accuracy: 0.950000
# Average loss: 0.160944, Train accuracy: 0.941895, Val accuracy: 0.950000

# %% [markdown]
# # Перенос обучения (transfer learning) - тренировать всю модель
#
# Второй вариант - добавить новый слой и обучать всю модель целиком.

# %%
import torch.nn as nn
import torch.optim as optim

model = models.resnet18(pretrained=True)
# TODO: Add a new output layer and train the whole model
# https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

model.type(torch.cuda.FloatTensor)
model.to(device)

parameters = model.parameters()   # Fill the right thing here!

loss = nn.CrossEntropyLoss().type(torch.cuda.FloatTensor)
optimizer = optim.SGD(parameters, lr=0.001, momentum=0.9)

loss_history, train_history, val_history = train_model(model, train_loader, val_loader, loss, optimizer, 5)
# Out:
# Average loss: 0.423088, Train accuracy: 0.810752, Val accuracy: 0.941304
# Average loss: 0.130523, Train accuracy: 0.947869, Val accuracy: 0.941304
# Average loss: 0.097537, Train accuracy: 0.968504, Val accuracy: 0.947826
# Average loss: 0.071530, Train accuracy: 0.976649, Val accuracy: 0.947826
# Average loss: 0.047593, Train accuracy: 0.990225, Val accuracy: 0.951087

# %% [markdown]
# # Перенос обучения (transfer learning) - разные скорости обучения для разных слоев
#
# И наконец последний вариант, который мы рассмотрим - использовать разные скорости обучения для новых и старых слоев

# %%
import torch.nn as nn
import torch.optim as optim

model = models.resnet18(pretrained=True)
# TODO: Add a new output layer
# Train new layer with learning speed 0.001 and old layers with 0.0001
# https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

model.type(torch.cuda.FloatTensor)
model.to(device)

loss = nn.CrossEntropyLoss().type(torch.cuda.FloatTensor)

params = []
for module in model.children():
    if module == model.fc:
        params.append({'params': module.parameters(), 'lr': 1e-3})
    else:
        params.append({'params': module.parameters()})

optimizer = optim.SGD(params, lr=1e-4, momentum=0.9) # Hint - look into what PyTorch optimizers let you configure!
loss_history, train_history, val_history = train_model(model, train_loader, val_loader, loss, optimizer, 5)
# Out:
# Average loss: 0.369027, Train accuracy: 0.823513, Val accuracy: 0.910870
# Average loss: 0.195944, Train accuracy: 0.925333, Val accuracy: 0.936957
# Average loss: 0.163261, Train accuracy: 0.941081, Val accuracy: 0.938043
# Average loss: 0.150195, Train accuracy: 0.941352, Val accuracy: 0.950000
# Average loss: 0.133071, Train accuracy: 0.949226, Val accuracy: 0.951087

# %% [markdown]
# # Визуализируем метрики и ошибки модели
#
# Попробуем посмотреть, где модель ошибается - визуализируем ложные срабатывания (false positives) и ложноотрицательные срабатывания (false negatives).
#
# Для этого мы прогоним модель через все примеры и сравним ее с истинными метками (ground truth).

# %%
from torch.utils.data.sampler import Sampler

class SubsetSampler(Sampler):
    r"""Samples elements with given indices sequentially

    Arguments:
        data_source (Dataset): dataset to sample from
        indices (ndarray): indices of the samples to take
    """

    def __init__(self, indices):
        self.indices = indices

    def __iter__(self):
        return (self.indices[i] for i in range(len(self.indices)))

    def __len__(self):
        return len(self.indices)
    
    
def evaluate_model(model, dataset, indices):
    """
    Computes predictions and ground truth labels for the indices of the dataset
    
    Returns: 
    predictions: np array of booleans of model predictions
    grount_truth: np array of boolean of actual labels of the dataset
    """
    model.eval() # Evaluation mode
    
    # TODO: Evaluate model on the list of indices and capture predictions
    # and ground truth labels
    # Hint: SubsetSampler above could be useful!
    subset_sampler = SubsetSampler(indices)
    eval_data_loader = torch.utils.data.DataLoader(dataset, sampler=subset_sampler, batch_size=batch_size)
    predictions = np.array([], dtype=int)
    ground_truth = np.array([], dtype=int)
    for x, y, _ in eval_data_loader:
        x_gpu = x.to(device)
        y_gpu = y.to(device)
        
        prediction = model(x_gpu)
        prediction_classes = torch.argmax(prediction, 1).cpu().numpy()
        predictions = np.append(predictions, prediction_classes)

        ground_truth = np.append(ground_truth, y.numpy())
    
    return predictions, ground_truth

predictions, gt = evaluate_model(model, train_dataset, val_indices)

# %% [markdown]
# И теперь можно визуализировать false positives и false negatives.

# %%
# TODO: Compute indices of the false positives on the validation set.
# Note those have to be indices of the original dataset
false_positive_indices = [val_idx for i, val_idx in enumerate(val_indices) if (predictions[i] and not gt[i])]
visualize_samples(orig_dataset, false_positive_indices, "False positives")

# TODO: Compute indices of the false negatives on the validation set.
# Note those have to be indices of the original dataset
false_negatives_indices = [val_idx for i, val_idx in enumerate(val_indices) if (not predictions[i] and gt[i])]
visualize_samples(orig_dataset, false_negatives_indices, "False negatives")

# %%
def binary_classification_metrics(prediction, ground_truth):
    # TODO: Implement this function!
    # We did this already it in the assignment1
    assert len(prediction) == len(ground_truth)

    tp = 0
    tn = 0
    fp = 0
    fn = 0

    for i in range(len(prediction)):
        if prediction[i]:
            if ground_truth[i]:
                tp += 1
            else:
                fp += 1
        else:
            if ground_truth[i]:
                fn += 1
            else:
                tn += 1

    if fp == 0:
        precision = 1.0
    else:
        precision = tp / (tp + fp)

    if fn == 0:
        recall = 1.0
    else:
        recall = tp / (tp + fn)

    f1 = 2 * tp / (2 * tp + fn + fp)

    return precision, recall, f1

precision, recall, f1 = binary_classification_metrics(predictions, gt)
print("F1: %4.3f, P: %4.3f, R: %4.3f" % (f1, precision, recall))
# Out:
# F1: 0.927, P: 0.935, R: 0.920

# %% [markdown]
# # Что будет в конце вы уже поняли
#
# Натренируйте лучшую модель на основе `resnet18`, меняя только процесс тренировки.
# Выбирайте лучшую модель по F1 score.
#
# Как всегда, не забываем:
# - побольше агментаций!
# - перебор гиперпараметров
# - различные оптимизаторы
# - какие слои тюнить
# - learning rate annealing
# - на какой эпохе останавливаться
#
# Наша цель - довести F1 score на validation set до значения, большего **0.9**.

# %%
# Train dataset with some augmentations

train_dataset_w_aug = HotdogOrNotDataset(train_folder, 
                       transform=transforms.Compose([
                           transforms.Resize((224, 224)),
                           transforms.RandomRotation(20, resample=Image.BILINEAR),
                           transforms.RandomHorizontalFlip(),
                           transforms.RandomVerticalFlip(),
                           transforms.ToTensor(),
                           # Use mean and std for pretrained models
                           # https://pytorch.org/docs/stable/torchvision/models.html
                           transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])                         
                       ])
                      )

batch_size = 64

data_size = len(dataset)
validation_fraction = .2

val_split = int(np.floor((validation_fraction) * data_size))
indices = list(range(data_size))
np.random.seed(42)
np.random.shuffle(indices)

val_indices, train_indices = indices[:val_split], indices[val_split:]

train_sampler = SubsetRandomSampler(train_indices)
val_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(train_dataset_w_aug, batch_size=batch_size, 
                                           sampler=train_sampler)
val_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
                                         sampler=val_sampler)

# %%
# Train whole model

import torch.nn as nn
import torch.optim as optim
import itertools

learning_rates = [1e-2, 1e-3, 1e-4]
regs = [1e-5, 1e-7, 1e-9]
gammas = [0.5, 0.2, 0.1]

best_f1 = None
best_model = None
model_histories = None
best_hyper_params = None

for hyper_params in itertools.product(learning_rates, regs, gammas):
    (lr, reg, gamma) = hyper_params
    print(hyper_params)
    
    model = models.resnet18(pretrained=True)
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, 2)

    model.type(torch.cuda.FloatTensor)
    model.to(device)

    parameters = model.parameters()

    loss = nn.CrossEntropyLoss().type(torch.cuda.FloatTensor)
    optimizer = optim.Adam(parameters, lr=lr, weight_decay=reg)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=gamma)

    loss_history, train_history, val_history = train_model(model, train_loader, val_loader, loss, optimizer, 30, scheduler)
    
    predictions, ground_truth = evaluate_model(model, train_dataset, val_indices)
    precision, recall, f1 = binary_classification_metrics(predictions, ground_truth)
    print("F1: %4.3f, P: %4.3f, R: %4.3f" % (f1, precision, recall))
    
    if best_f1 is None or f1 > best_f1:
        best_f1 = f1
        best_model = model
        model_histories = (loss_history, train_history, val_history)
        best_hyper_params = hyper_params
# Out:
# (0.01, 1e-05, 0.5)
# Average loss: 0.834615, Train accuracy: 0.663046, Val accuracy: 0.651087
# Average loss: 0.548693, Train accuracy: 0.699158, Val accuracy: 0.682609
# Average loss: 0.508577, Train accuracy: 0.738528, Val accuracy: 0.713043
# Average loss: 0.478468, Train accuracy: 0.761879, Val accuracy: 0.694565
# Average loss: 0.465767, Train accuracy: 0.767852, Val accuracy: 0.684783
# Average loss: 0.451748, Train accuracy: 0.778985, Val accuracy: 0.764130
# Average loss: 0.427993, Train accuracy: 0.789845, Val accuracy: 0.781522
# Average loss: 0.431848, Train accuracy: 0.792017, Val accuracy: 0.735870
# Average loss: 0.420833, Train accuracy: 0.800434, Val accuracy: 0.775000
# Average loss: 0.426148, Train accuracy: 0.805865, Val accuracy: 0.768478
# Average loss: 0.393294, Train accuracy: 0.818355, Val accuracy: 0.823913
# Average loss: 0.374321, Train accuracy: 0.832745, Val accuracy: 0.773913
# Average loss: 0.372106, Train accuracy: 0.825957, Val accuracy: 0.830435
# Average loss: 0.369323, Train accuracy: 0.825143, Val accuracy: 0.784783
# Average loss: 0.384807, Train accuracy: 0.826772, Val accuracy: 0.802174
# Average loss: 0.365208, Train accuracy: 0.834917, Val accuracy: 0.827174
# Average loss: 0.360151, Train accuracy: 0.837632, Val accuracy: 0.814130
# Average loss: 0.374154, Train accuracy: 0.832202, Val accuracy: 0.805435
# Average loss: 0.417006, Train accuracy: 0.822699, Val accuracy: 0.735870
# Average loss: 0.410926, Train accuracy: 0.815911, Val accuracy: 0.801087
# Average loss: 0.369802, Train accuracy: 0.834103, Val accuracy: 0.820652
# Average loss: 0.356060, Train accuracy: 0.840619, Val accuracy: 0.834783
# Average loss: 0.349768, Train accuracy: 0.845778, Val accuracy: 0.817391
# Average loss: 0.344434, Train accuracy: 0.846864, Val accuracy: 0.814130
# Average loss: 0.351850, Train accuracy: 0.838718, Val accuracy: 0.821739
# Average loss: 0.346480, Train accuracy: 0.851751, Val accuracy: 0.834783
# Average loss: 0.343938, Train accuracy: 0.846592, Val accuracy: 0.826087
# Average loss: 0.333652, Train accuracy: 0.852023, Val accuracy: 0.819565
# Average loss: 0.346207, Train accuracy: 0.845506, Val accuracy: 0.851087
# Average loss: 0.342839, Train accuracy: 0.848222, Val accuracy: 0.841304
# F1: 0.753, P: 0.794, R: 0.717
# (0.01, 1e-05, 0.2)
# Average loss: 0.730660, Train accuracy: 0.659245, Val accuracy: 0.631522
# Average loss: 0.557445, Train accuracy: 0.705946, Val accuracy: 0.607609
# Average loss: 0.538462, Train accuracy: 0.699158, Val accuracy: 0.677174
# Average loss: 0.496733, Train accuracy: 0.744773, Val accuracy: 0.661957
# Average loss: 0.674358, Train accuracy: 0.684496, Val accuracy: 0.659783
# Average loss: 0.534419, Train accuracy: 0.701873, Val accuracy: 0.715217
# Average loss: 0.498478, Train accuracy: 0.736356, Val accuracy: 0.667391
# Average loss: 0.488398, Train accuracy: 0.751833, Val accuracy: 0.743478
# Average loss: 0.466480, Train accuracy: 0.778985, Val accuracy: 0.725000
# Average loss: 0.442337, Train accuracy: 0.787673, Val accuracy: 0.752174
# Average loss: 0.402899, Train accuracy: 0.808037, Val accuracy: 0.798913
# Average loss: 0.389577, Train accuracy: 0.815639, Val accuracy: 0.806522
# Average loss: 0.382102, Train accuracy: 0.824328, Val accuracy: 0.803261
# Average loss: 0.383058, Train accuracy: 0.823785, Val accuracy: 0.821739
# Average loss: 0.381135, Train accuracy: 0.819441, Val accuracy: 0.816304
# Average loss: 0.376234, Train accuracy: 0.824328, Val accuracy: 0.811957
# Average loss: 0.366128, Train accuracy: 0.830301, Val accuracy: 0.810870
# Average loss: 0.365653, Train accuracy: 0.835189, Val accuracy: 0.826087
# Average loss: 0.372418, Train accuracy: 0.826500, Val accuracy: 0.814130
# Average loss: 0.361497, Train accuracy: 0.829487, Val accuracy: 0.807609
# Average loss: 0.347764, Train accuracy: 0.836546, Val accuracy: 0.832609
# Average loss: 0.341455, Train accuracy: 0.843606, Val accuracy: 0.829348
# Average loss: 0.338002, Train accuracy: 0.841977, Val accuracy: 0.827174
# Average loss: 0.336421, Train accuracy: 0.844963, Val accuracy: 0.833696
# Average loss: 0.336079, Train accuracy: 0.843606, Val accuracy: 0.830435
# Average loss: 0.332751, Train accuracy: 0.846049, Val accuracy: 0.832609
# Average loss: 0.337121, Train accuracy: 0.851751, Val accuracy: 0.832609
# Average loss: 0.331147, Train accuracy: 0.851751, Val accuracy: 0.834783
# Average loss: 0.330108, Train accuracy: 0.850665, Val accuracy: 0.832609
# Average loss: 0.334183, Train accuracy: 0.849579, Val accuracy: 0.830435
# F1: 0.755, P: 0.742, R: 0.768
# (0.01, 1e-05, 0.1)
# Average loss: 0.822033, Train accuracy: 0.677165, Val accuracy: 0.611957
# Average loss: 0.569183, Train accuracy: 0.707032, Val accuracy: 0.693478
# Average loss: 0.547285, Train accuracy: 0.730383, Val accuracy: 0.663043
# Average loss: 0.536523, Train accuracy: 0.718708, Val accuracy: 0.710870
# Average loss: 0.468768, Train accuracy: 0.763508, Val accuracy: 0.744565
# Average loss: 0.459819, Train accuracy: 0.777898, Val accuracy: 0.751087
# Average loss: 0.458665, Train accuracy: 0.776541, Val accuracy: 0.640217
# Average loss: 0.460241, Train accuracy: 0.780342, Val accuracy: 0.753261
# Average loss: 0.455737, Train accuracy: 0.781971, Val accuracy: 0.771739
# Average loss: 0.421224, Train accuracy: 0.798262, Val accuracy: 0.721739
# Average loss: 0.395128, Train accuracy: 0.817269, Val accuracy: 0.804348
# Average loss: 0.385279, Train accuracy: 0.823785, Val accuracy: 0.825000
# Average loss: 0.369319, Train accuracy: 0.832745, Val accuracy: 0.826087
# Average loss: 0.364294, Train accuracy: 0.830844, Val accuracy: 0.825000
# Average loss: 0.365986, Train accuracy: 0.837089, Val accuracy: 0.820652
# Average loss: 0.356160, Train accuracy: 0.831116, Val accuracy: 0.819565
# Average loss: 0.360430, Train accuracy: 0.837361, Val accuracy: 0.823913
# Average loss: 0.359214, Train accuracy: 0.840076, Val accuracy: 0.807609
# Average loss: 0.360201, Train accuracy: 0.837632, Val accuracy: 0.813043
# Average loss: 0.353515, Train accuracy: 0.837904, Val accuracy: 0.835870
# Average loss: 0.349458, Train accuracy: 0.842520, Val accuracy: 0.834783
# Average loss: 0.343894, Train accuracy: 0.842248, Val accuracy: 0.840217
# Average loss: 0.337249, Train accuracy: 0.847950, Val accuracy: 0.838043
# Average loss: 0.348055, Train accuracy: 0.842248, Val accuracy: 0.834783
# Average loss: 0.336972, Train accuracy: 0.847950, Val accuracy: 0.850000
# Average loss: 0.343283, Train accuracy: 0.842791, Val accuracy: 0.835870
# Average loss: 0.339029, Train accuracy: 0.843606, Val accuracy: 0.839130
# Average loss: 0.340626, Train accuracy: 0.845778, Val accuracy: 0.842391
# Average loss: 0.338920, Train accuracy: 0.851751, Val accuracy: 0.838043
# Average loss: 0.342682, Train accuracy: 0.847135, Val accuracy: 0.842391
# F1: 0.754, P: 0.759, R: 0.749
# (0.01, 1e-07, 0.5)
# Average loss: 0.734360, Train accuracy: 0.652186, Val accuracy: 0.661957
# Average loss: 0.591704, Train accuracy: 0.690470, Val accuracy: 0.702174
# Average loss: 0.526095, Train accuracy: 0.712734, Val accuracy: 0.467391
# Average loss: 0.609737, Train accuracy: 0.690198, Val accuracy: 0.641304
# Average loss: 0.540859, Train accuracy: 0.705675, Val accuracy: 0.698913
# Average loss: 0.527319, Train accuracy: 0.703774, Val accuracy: 0.661957
# Average loss: 0.520081, Train accuracy: 0.712191, Val accuracy: 0.661957
# Average loss: 0.512477, Train accuracy: 0.704317, Val accuracy: 0.717391
# Average loss: 0.505727, Train accuracy: 0.731197, Val accuracy: 0.661957
# Average loss: 0.515723, Train accuracy: 0.714906, Val accuracy: 0.714130
# Average loss: 0.473790, Train accuracy: 0.746674, Val accuracy: 0.778261
# Average loss: 0.456984, Train accuracy: 0.774369, Val accuracy: 0.746739
# Average loss: 0.428477, Train accuracy: 0.787673, Val accuracy: 0.773913
# Average loss: 0.435435, Train accuracy: 0.785229, Val accuracy: 0.740217
# Average loss: 0.425353, Train accuracy: 0.799077, Val accuracy: 0.784783
# Average loss: 0.403738, Train accuracy: 0.806408, Val accuracy: 0.761957
# Average loss: 0.400740, Train accuracy: 0.811838, Val accuracy: 0.798913
# Average loss: 0.399768, Train accuracy: 0.816454, Val accuracy: 0.779348
# Average loss: 0.387602, Train accuracy: 0.818355, Val accuracy: 0.804348
# Average loss: 0.379002, Train accuracy: 0.831116, Val accuracy: 0.779348
# Average loss: 0.380485, Train accuracy: 0.825143, Val accuracy: 0.816304
# Average loss: 0.359715, Train accuracy: 0.836003, Val accuracy: 0.833696
# Average loss: 0.357408, Train accuracy: 0.836818, Val accuracy: 0.819565
# Average loss: 0.350143, Train accuracy: 0.841434, Val accuracy: 0.828261
# Average loss: 0.347049, Train accuracy: 0.843334, Val accuracy: 0.818478
# Average loss: 0.346937, Train accuracy: 0.843334, Val accuracy: 0.789130
# Average loss: 0.348006, Train accuracy: 0.845506, Val accuracy: 0.814130
# Average loss: 0.356549, Train accuracy: 0.836275, Val accuracy: 0.803261
# Average loss: 0.349670, Train accuracy: 0.842520, Val accuracy: 0.832609
# Average loss: 0.361962, Train accuracy: 0.843063, Val accuracy: 0.819565
# F1: 0.696, P: 0.803, R: 0.614
# (0.01, 1e-07, 0.2)
# Average loss: 0.873443, Train accuracy: 0.651371, Val accuracy: 0.636957
# Average loss: 0.647960, Train accuracy: 0.685582, Val accuracy: 0.671739
# Average loss: 0.571753, Train accuracy: 0.711105, Val accuracy: 0.677174
# Average loss: 0.493987, Train accuracy: 0.747760, Val accuracy: 0.700000
# Average loss: 0.487105, Train accuracy: 0.751833, Val accuracy: 0.671739
# Average loss: 0.462621, Train accuracy: 0.773283, Val accuracy: 0.698913
# Average loss: 0.440475, Train accuracy: 0.778985, Val accuracy: 0.764130
# Average loss: 0.449031, Train accuracy: 0.787130, Val accuracy: 0.713043
# Average loss: 0.424445, Train accuracy: 0.796905, Val accuracy: 0.806522
# Average loss: 0.403815, Train accuracy: 0.808580, Val accuracy: 0.697826
# Average loss: 0.374591, Train accuracy: 0.832474, Val accuracy: 0.813043
# Average loss: 0.365892, Train accuracy: 0.837361, Val accuracy: 0.816304
# Average loss: 0.359364, Train accuracy: 0.835189, Val accuracy: 0.830435
# Average loss: 0.352316, Train accuracy: 0.837361, Val accuracy: 0.821739
# Average loss: 0.358113, Train accuracy: 0.837089, Val accuracy: 0.836957
# Average loss: 0.345974, Train accuracy: 0.841705, Val accuracy: 0.819565
# Average loss: 0.352362, Train accuracy: 0.842520, Val accuracy: 0.817391
# Average loss: 0.347780, Train accuracy: 0.845506, Val accuracy: 0.806522
# Average loss: 0.342369, Train accuracy: 0.846049, Val accuracy: 0.834783
# Average loss: 0.341454, Train accuracy: 0.842520, Val accuracy: 0.811957
# Average loss: 0.339653, Train accuracy: 0.848765, Val accuracy: 0.833696
# Average loss: 0.325435, Train accuracy: 0.849036, Val accuracy: 0.839130
# Average loss: 0.327976, Train accuracy: 0.848493, Val accuracy: 0.838043
# Average loss: 0.320145, Train accuracy: 0.855281, Val accuracy: 0.838043
# Average loss: 0.321929, Train accuracy: 0.844963, Val accuracy: 0.841304
# Average loss: 0.324099, Train accuracy: 0.857182, Val accuracy: 0.856522
# Average loss: 0.317262, Train accuracy: 0.857996, Val accuracy: 0.840217
# Average loss: 0.318367, Train accuracy: 0.855281, Val accuracy: 0.840217
# Average loss: 0.314101, Train accuracy: 0.858539, Val accuracy: 0.847826
# Average loss: 0.317899, Train accuracy: 0.850937, Val accuracy: 0.850000
# F1: 0.732, P: 0.786, R: 0.685
# (0.01, 1e-07, 0.1)
# Average loss: 0.722157, Train accuracy: 0.656802, Val accuracy: 0.642391
# Average loss: 0.532330, Train accuracy: 0.728754, Val accuracy: 0.702174
# Average loss: 0.515654, Train accuracy: 0.733913, Val accuracy: 0.708696
# Average loss: 0.564395, Train accuracy: 0.752376, Val accuracy: 0.431522
# Average loss: 0.649137, Train accuracy: 0.714363, Val accuracy: 0.654348
# Average loss: 0.535875, Train accuracy: 0.715721, Val accuracy: 0.731522
# Average loss: 0.496582, Train accuracy: 0.750475, Val accuracy: 0.668478
# Average loss: 0.474127, Train accuracy: 0.767309, Val accuracy: 0.634783
# Average loss: 0.478839, Train accuracy: 0.765137, Val accuracy: 0.736957
# Average loss: 0.431021, Train accuracy: 0.795547, Val accuracy: 0.721739
# Average loss: 0.412944, Train accuracy: 0.807765, Val accuracy: 0.810870
# Average loss: 0.392642, Train accuracy: 0.816182, Val accuracy: 0.805435
# Average loss: 0.390508, Train accuracy: 0.820255, Val accuracy: 0.807609
# Average loss: 0.381617, Train accuracy: 0.821884, Val accuracy: 0.813043
# Average loss: 0.382230, Train accuracy: 0.821884, Val accuracy: 0.814130
# Average loss: 0.380464, Train accuracy: 0.828944, Val accuracy: 0.818478
# Average loss: 0.371205, Train accuracy: 0.826772, Val accuracy: 0.821739
# Average loss: 0.369868, Train accuracy: 0.828944, Val accuracy: 0.814130
# Average loss: 0.366531, Train accuracy: 0.832202, Val accuracy: 0.820652
# Average loss: 0.359777, Train accuracy: 0.837361, Val accuracy: 0.826087
# Average loss: 0.355746, Train accuracy: 0.843877, Val accuracy: 0.831522
# Average loss: 0.347844, Train accuracy: 0.842248, Val accuracy: 0.829348
# Average loss: 0.355088, Train accuracy: 0.842248, Val accuracy: 0.838043
# Average loss: 0.355273, Train accuracy: 0.834917, Val accuracy: 0.834783
# Average loss: 0.345449, Train accuracy: 0.846049, Val accuracy: 0.821739
# Average loss: 0.350260, Train accuracy: 0.841434, Val accuracy: 0.833696
# Average loss: 0.345200, Train accuracy: 0.842248, Val accuracy: 0.834783
# Average loss: 0.346227, Train accuracy: 0.844692, Val accuracy: 0.833696
# Average loss: 0.349254, Train accuracy: 0.843606, Val accuracy: 0.835870
# Average loss: 0.349919, Train accuracy: 0.844692, Val accuracy: 0.829348
# F1: 0.745, P: 0.753, R: 0.736
# (0.01, 1e-09, 0.5)
# Average loss: 0.722300, Train accuracy: 0.664676, Val accuracy: 0.661957
# Average loss: 0.588432, Train accuracy: 0.698344, Val accuracy: 0.668478
# Average loss: 0.562240, Train accuracy: 0.710562, Val accuracy: 0.660870
# Average loss: 0.531873, Train accuracy: 0.727939, Val accuracy: 0.720652
# Average loss: 0.488922, Train accuracy: 0.753462, Val accuracy: 0.680435
# Average loss: 0.513672, Train accuracy: 0.741244, Val accuracy: 0.710870
# Average loss: 0.508814, Train accuracy: 0.746131, Val accuracy: 0.702174
# Average loss: 0.476065, Train accuracy: 0.767309, Val accuracy: 0.717391
# Average loss: 0.462521, Train accuracy: 0.773283, Val accuracy: 0.695652
# Average loss: 0.449594, Train accuracy: 0.785772, Val accuracy: 0.711957
# Average loss: 0.424245, Train accuracy: 0.797991, Val accuracy: 0.761957
# Average loss: 0.423010, Train accuracy: 0.795276, Val accuracy: 0.781522
# Average loss: 0.426855, Train accuracy: 0.809123, Val accuracy: 0.793478
# Average loss: 0.412363, Train accuracy: 0.812381, Val accuracy: 0.783696
# Average loss: 0.397751, Train accuracy: 0.819984, Val accuracy: 0.814130
# Average loss: 0.376769, Train accuracy: 0.828944, Val accuracy: 0.790217
# Average loss: 0.400085, Train accuracy: 0.819984, Val accuracy: 0.817391
# Average loss: 0.390122, Train accuracy: 0.824871, Val accuracy: 0.822826
# Average loss: 0.386382, Train accuracy: 0.822970, Val accuracy: 0.809783
# Average loss: 0.369035, Train accuracy: 0.832474, Val accuracy: 0.826087
# Average loss: 0.368225, Train accuracy: 0.843334, Val accuracy: 0.831522
# Average loss: 0.350392, Train accuracy: 0.841434, Val accuracy: 0.826087
# Average loss: 0.349396, Train accuracy: 0.846864, Val accuracy: 0.843478
# Average loss: 0.336853, Train accuracy: 0.856910, Val accuracy: 0.835870
# Average loss: 0.348193, Train accuracy: 0.841162, Val accuracy: 0.785870
# Average loss: 0.342838, Train accuracy: 0.844420, Val accuracy: 0.838043
# Average loss: 0.340241, Train accuracy: 0.852023, Val accuracy: 0.823913
# Average loss: 0.338708, Train accuracy: 0.854195, Val accuracy: 0.828261
# Average loss: 0.340446, Train accuracy: 0.850394, Val accuracy: 0.825000
# Average loss: 0.328738, Train accuracy: 0.855281, Val accuracy: 0.828261
# F1: 0.691, P: 0.850, R: 0.582
# (0.01, 1e-09, 0.2)
# Average loss: 0.827376, Train accuracy: 0.663589, Val accuracy: 0.661957
# Average loss: 0.642170, Train accuracy: 0.652729, Val accuracy: 0.661957
# Average loss: 0.545910, Train accuracy: 0.713820, Val accuracy: 0.686957
# Average loss: 0.518095, Train accuracy: 0.722509, Val accuracy: 0.744565
# Average loss: 0.497530, Train accuracy: 0.737442, Val accuracy: 0.665217
# Average loss: 0.479610, Train accuracy: 0.761064, Val accuracy: 0.690217
# Average loss: 0.486770, Train accuracy: 0.761336, Val accuracy: 0.707609
# Average loss: 0.467384, Train accuracy: 0.767309, Val accuracy: 0.423913
# Average loss: 0.435655, Train accuracy: 0.784958, Val accuracy: 0.684783
# Average loss: 0.448025, Train accuracy: 0.780885, Val accuracy: 0.768478
# Average loss: 0.410090, Train accuracy: 0.802878, Val accuracy: 0.786957
# Average loss: 0.398637, Train accuracy: 0.813196, Val accuracy: 0.805435
# Average loss: 0.393376, Train accuracy: 0.815911, Val accuracy: 0.782609
# Average loss: 0.379777, Train accuracy: 0.825143, Val accuracy: 0.782609
# Average loss: 0.381339, Train accuracy: 0.826772, Val accuracy: 0.814130
# Average loss: 0.376439, Train accuracy: 0.830030, Val accuracy: 0.820652
# Average loss: 0.378394, Train accuracy: 0.832745, Val accuracy: 0.784783
# Average loss: 0.369811, Train accuracy: 0.836003, Val accuracy: 0.822826
# Average loss: 0.364405, Train accuracy: 0.840348, Val accuracy: 0.790217
# Average loss: 0.362230, Train accuracy: 0.834103, Val accuracy: 0.807609
# Average loss: 0.348753, Train accuracy: 0.839261, Val accuracy: 0.838043
# Average loss: 0.335977, Train accuracy: 0.850937, Val accuracy: 0.836957
# Average loss: 0.336760, Train accuracy: 0.847407, Val accuracy: 0.840217
# Average loss: 0.332992, Train accuracy: 0.851480, Val accuracy: 0.833696
# Average loss: 0.326264, Train accuracy: 0.855010, Val accuracy: 0.831522
# Average loss: 0.335112, Train accuracy: 0.853380, Val accuracy: 0.833696
# Average loss: 0.333067, Train accuracy: 0.854466, Val accuracy: 0.848913
# Average loss: 0.333034, Train accuracy: 0.848765, Val accuracy: 0.838043
# Average loss: 0.319958, Train accuracy: 0.854195, Val accuracy: 0.836957
# Average loss: 0.330051, Train accuracy: 0.856367, Val accuracy: 0.839130
# F1: 0.726, P: 0.789, R: 0.672
# (0.01, 1e-09, 0.1)
# Average loss: 0.730630, Train accuracy: 0.657345, Val accuracy: 0.668478
# Average loss: 0.566627, Train accuracy: 0.709476, Val accuracy: 0.694565
# Average loss: 0.522994, Train accuracy: 0.729568, Val accuracy: 0.673913
# Average loss: 0.483079, Train accuracy: 0.754819, Val accuracy: 0.728261
# Average loss: 0.471813, Train accuracy: 0.765680, Val accuracy: 0.726087
# Average loss: 0.601001, Train accuracy: 0.742601, Val accuracy: 0.669565
# Average loss: 0.639789, Train accuracy: 0.693999, Val accuracy: 0.645652
# Average loss: 0.516953, Train accuracy: 0.716264, Val accuracy: 0.698913
# Average loss: 0.486601, Train accuracy: 0.747488, Val accuracy: 0.735870
# Average loss: 0.467607, Train accuracy: 0.762693, Val accuracy: 0.755435
# Average loss: 0.444674, Train accuracy: 0.779799, Val accuracy: 0.776087
# Average loss: 0.437826, Train accuracy: 0.787130, Val accuracy: 0.759783
# Average loss: 0.432367, Train accuracy: 0.784958, Val accuracy: 0.773913
# Average loss: 0.422325, Train accuracy: 0.793646, Val accuracy: 0.794565
# Average loss: 0.423204, Train accuracy: 0.797448, Val accuracy: 0.785870
# Average loss: 0.420467, Train accuracy: 0.803150, Val accuracy: 0.775000
# Average loss: 0.414373, Train accuracy: 0.805865, Val accuracy: 0.768478
# Average loss: 0.406488, Train accuracy: 0.807222, Val accuracy: 0.761957
# Average loss: 0.409229, Train accuracy: 0.806408, Val accuracy: 0.814130
# Average loss: 0.394368, Train accuracy: 0.820255, Val accuracy: 0.806522
# Average loss: 0.374866, Train accuracy: 0.821070, Val accuracy: 0.813043
# Average loss: 0.377221, Train accuracy: 0.831930, Val accuracy: 0.805435
# Average loss: 0.375889, Train accuracy: 0.830844, Val accuracy: 0.817391
# Average loss: 0.374759, Train accuracy: 0.827043, Val accuracy: 0.806522
# Average loss: 0.376049, Train accuracy: 0.828944, Val accuracy: 0.803261
# Average loss: 0.364244, Train accuracy: 0.835189, Val accuracy: 0.819565
# Average loss: 0.364715, Train accuracy: 0.834103, Val accuracy: 0.822826
# Average loss: 0.364656, Train accuracy: 0.833288, Val accuracy: 0.816304
# Average loss: 0.365907, Train accuracy: 0.829758, Val accuracy: 0.814130
# Average loss: 0.366122, Train accuracy: 0.834917, Val accuracy: 0.826087
# F1: 0.714, P: 0.787, R: 0.653
# (0.001, 1e-05, 0.5)
# Average loss: 0.387578, Train accuracy: 0.849036, Val accuracy: 0.833696
# Average loss: 0.250411, Train accuracy: 0.896552, Val accuracy: 0.777174
# Average loss: 0.223155, Train accuracy: 0.910942, Val accuracy: 0.841304
# Average loss: 0.220941, Train accuracy: 0.914472, Val accuracy: 0.871739
# Average loss: 0.206953, Train accuracy: 0.911757, Val accuracy: 0.879348
# Average loss: 0.198224, Train accuracy: 0.918273, Val accuracy: 0.865217
# Average loss: 0.184422, Train accuracy: 0.926962, Val accuracy: 0.840217
# Average loss: 0.200056, Train accuracy: 0.917187, Val accuracy: 0.888043
# Average loss: 0.159064, Train accuracy: 0.940809, Val accuracy: 0.814130
# Average loss: 0.162452, Train accuracy: 0.932935, Val accuracy: 0.844565
# Average loss: 0.111122, Train accuracy: 0.958458, Val accuracy: 0.913043
# Average loss: 0.087808, Train accuracy: 0.964974, Val accuracy: 0.931522
# Average loss: 0.087723, Train accuracy: 0.966875, Val accuracy: 0.919565
# Average loss: 0.083989, Train accuracy: 0.965789, Val accuracy: 0.935870
# Average loss: 0.056529, Train accuracy: 0.978822, Val accuracy: 0.916304
# Average loss: 0.074656, Train accuracy: 0.972577, Val accuracy: 0.909783
# Average loss: 0.086001, Train accuracy: 0.964703, Val accuracy: 0.902174
# Average loss: 0.072550, Train accuracy: 0.972848, Val accuracy: 0.917391
# Average loss: 0.063029, Train accuracy: 0.973934, Val accuracy: 0.908696
# Average loss: 0.088379, Train accuracy: 0.968232, Val accuracy: 0.911957
# Average loss: 0.055619, Train accuracy: 0.981537, Val accuracy: 0.936957
# Average loss: 0.025575, Train accuracy: 0.991854, Val accuracy: 0.933696
# Average loss: 0.026666, Train accuracy: 0.992126, Val accuracy: 0.940217
# Average loss: 0.020307, Train accuracy: 0.992398, Val accuracy: 0.944565
# Average loss: 0.024212, Train accuracy: 0.992126, Val accuracy: 0.920652
# Average loss: 0.019539, Train accuracy: 0.991854, Val accuracy: 0.932609
# Average loss: 0.018031, Train accuracy: 0.993212, Val accuracy: 0.927174
# Average loss: 0.012675, Train accuracy: 0.995656, Val accuracy: 0.929348
# Average loss: 0.017022, Train accuracy: 0.993755, Val accuracy: 0.926087
# Average loss: 0.019983, Train accuracy: 0.993755, Val accuracy: 0.935870
# F1: 0.898, P: 0.868, R: 0.929
# (0.001, 1e-05, 0.2)
# Average loss: 0.433237, Train accuracy: 0.816182, Val accuracy: 0.838043
# Average loss: 0.304800, Train accuracy: 0.866685, Val accuracy: 0.854348
# Average loss: 0.254243, Train accuracy: 0.896552, Val accuracy: 0.861957
# Average loss: 0.248783, Train accuracy: 0.896009, Val accuracy: 0.856522
# Average loss: 0.240737, Train accuracy: 0.899810, Val accuracy: 0.801087
# Average loss: 0.219523, Train accuracy: 0.913114, Val accuracy: 0.875000
# Average loss: 0.219747, Train accuracy: 0.910671, Val accuracy: 0.827174
# Average loss: 0.189122, Train accuracy: 0.922346, Val accuracy: 0.878261
# Average loss: 0.185500, Train accuracy: 0.932392, Val accuracy: 0.895652
# Average loss: 0.182044, Train accuracy: 0.931578, Val accuracy: 0.906522
# Average loss: 0.119023, Train accuracy: 0.951398, Val accuracy: 0.918478
# Average loss: 0.092661, Train accuracy: 0.966875, Val accuracy: 0.916304
# Average loss: 0.082929, Train accuracy: 0.967961, Val accuracy: 0.919565
# Average loss: 0.067759, Train accuracy: 0.978007, Val accuracy: 0.921739
# Average loss: 0.072347, Train accuracy: 0.973391, Val accuracy: 0.926087
# Average loss: 0.058729, Train accuracy: 0.979093, Val accuracy: 0.906522
# Average loss: 0.054881, Train accuracy: 0.979365, Val accuracy: 0.934783
# Average loss: 0.043999, Train accuracy: 0.985067, Val accuracy: 0.926087
# Average loss: 0.059209, Train accuracy: 0.976378, Val accuracy: 0.927174
# Average loss: 0.050222, Train accuracy: 0.985610, Val accuracy: 0.930435
# Average loss: 0.030110, Train accuracy: 0.990768, Val accuracy: 0.929348
# Average loss: 0.024629, Train accuracy: 0.993212, Val accuracy: 0.940217
# Average loss: 0.025765, Train accuracy: 0.992669, Val accuracy: 0.934783
# Average loss: 0.021960, Train accuracy: 0.993755, Val accuracy: 0.939130
# Average loss: 0.019708, Train accuracy: 0.994027, Val accuracy: 0.942391
# Average loss: 0.019517, Train accuracy: 0.994298, Val accuracy: 0.932609
# Average loss: 0.014176, Train accuracy: 0.996199, Val accuracy: 0.941304
# Average loss: 0.020270, Train accuracy: 0.994027, Val accuracy: 0.933696
# Average loss: 0.014669, Train accuracy: 0.994841, Val accuracy: 0.934783
# Average loss: 0.014243, Train accuracy: 0.997013, Val accuracy: 0.934783
# F1: 0.926, P: 0.932, R: 0.920
# (0.001, 1e-05, 0.1)
# Average loss: 0.423613, Train accuracy: 0.825143, Val accuracy: 0.864130
# Average loss: 0.267195, Train accuracy: 0.884333, Val accuracy: 0.810870
# Average loss: 0.263384, Train accuracy: 0.891393, Val accuracy: 0.850000
# Average loss: 0.236844, Train accuracy: 0.901711, Val accuracy: 0.882609
# Average loss: 0.217573, Train accuracy: 0.910671, Val accuracy: 0.855435
# Average loss: 0.201762, Train accuracy: 0.917187, Val accuracy: 0.903261
# Average loss: 0.191355, Train accuracy: 0.922074, Val accuracy: 0.871739
# Average loss: 0.184396, Train accuracy: 0.927505, Val accuracy: 0.885870
# Average loss: 0.204374, Train accuracy: 0.921803, Val accuracy: 0.870652
# Average loss: 0.168417, Train accuracy: 0.939995, Val accuracy: 0.872826
# Average loss: 0.139282, Train accuracy: 0.952484, Val accuracy: 0.919565
# Average loss: 0.096819, Train accuracy: 0.965517, Val accuracy: 0.921739
# Average loss: 0.081529, Train accuracy: 0.973391, Val accuracy: 0.934783
# Average loss: 0.080232, Train accuracy: 0.969862, Val accuracy: 0.931522
# Average loss: 0.063413, Train accuracy: 0.978550, Val accuracy: 0.932609
# Average loss: 0.062413, Train accuracy: 0.977464, Val accuracy: 0.928261
# Average loss: 0.060351, Train accuracy: 0.978279, Val accuracy: 0.929348
# Average loss: 0.042349, Train accuracy: 0.986153, Val accuracy: 0.930435
# Average loss: 0.042253, Train accuracy: 0.986967, Val accuracy: 0.938043
# Average loss: 0.044081, Train accuracy: 0.986153, Val accuracy: 0.928261
# Average loss: 0.034246, Train accuracy: 0.988596, Val accuracy: 0.928261
# Average loss: 0.036342, Train accuracy: 0.988053, Val accuracy: 0.926087
# Average loss: 0.033812, Train accuracy: 0.989139, Val accuracy: 0.930435
# Average loss: 0.026984, Train accuracy: 0.990768, Val accuracy: 0.923913
# Average loss: 0.031140, Train accuracy: 0.989682, Val accuracy: 0.931522
# Average loss: 0.029683, Train accuracy: 0.991583, Val accuracy: 0.927174
# Average loss: 0.028866, Train accuracy: 0.991040, Val accuracy: 0.939130
# Average loss: 0.023886, Train accuracy: 0.992398, Val accuracy: 0.930435
# Average loss: 0.031680, Train accuracy: 0.989411, Val accuracy: 0.933696
# Average loss: 0.025770, Train accuracy: 0.992398, Val accuracy: 0.926087
# F1: 0.905, P: 0.893, R: 0.916
# (0.001, 1e-07, 0.5)
# Average loss: 0.396003, Train accuracy: 0.838447, Val accuracy: 0.850000
# Average loss: 0.254855, Train accuracy: 0.889764, Val accuracy: 0.746739
# Average loss: 0.239830, Train accuracy: 0.903068, Val accuracy: 0.768478
# Average loss: 0.229151, Train accuracy: 0.910399, Val accuracy: 0.859783
# Average loss: 0.184458, Train accuracy: 0.928591, Val accuracy: 0.875000
# Average loss: 0.215835, Train accuracy: 0.913386, Val accuracy: 0.717391
# Average loss: 0.211250, Train accuracy: 0.910671, Val accuracy: 0.895652
# Average loss: 0.178772, Train accuracy: 0.929948, Val accuracy: 0.886957
# Average loss: 0.176314, Train accuracy: 0.929405, Val accuracy: 0.891304
# Average loss: 0.143979, Train accuracy: 0.942438, Val accuracy: 0.880435
# Average loss: 0.105389, Train accuracy: 0.957915, Val accuracy: 0.911957
# Average loss: 0.091832, Train accuracy: 0.969862, Val accuracy: 0.909783
# Average loss: 0.102911, Train accuracy: 0.961444, Val accuracy: 0.918478
# Average loss: 0.076695, Train accuracy: 0.973663, Val accuracy: 0.913043
# Average loss: 0.076669, Train accuracy: 0.969862, Val accuracy: 0.907609
# Average loss: 0.075524, Train accuracy: 0.972034, Val accuracy: 0.897826
# Average loss: 0.078655, Train accuracy: 0.968232, Val accuracy: 0.909783
# Average loss: 0.061542, Train accuracy: 0.976378, Val accuracy: 0.918478
# Average loss: 0.068265, Train accuracy: 0.971491, Val accuracy: 0.917391
# Average loss: 0.076642, Train accuracy: 0.972577, Val accuracy: 0.902174
# Average loss: 0.046097, Train accuracy: 0.983980, Val accuracy: 0.922826
# Average loss: 0.029656, Train accuracy: 0.990225, Val accuracy: 0.927174
# Average loss: 0.030600, Train accuracy: 0.989682, Val accuracy: 0.922826
# Average loss: 0.023542, Train accuracy: 0.991583, Val accuracy: 0.921739
# Average loss: 0.024004, Train accuracy: 0.991040, Val accuracy: 0.929348
# Average loss: 0.014906, Train accuracy: 0.995113, Val accuracy: 0.916304
# Average loss: 0.017735, Train accuracy: 0.994298, Val accuracy: 0.920652
# Average loss: 0.023011, Train accuracy: 0.991040, Val accuracy: 0.908696
# Average loss: 0.027525, Train accuracy: 0.990225, Val accuracy: 0.925000
# Average loss: 0.017351, Train accuracy: 0.994298, Val accuracy: 0.938043
# F1: 0.904, P: 0.932, R: 0.878
# (0.001, 1e-07, 0.2)
# Average loss: 0.397898, Train accuracy: 0.845235, Val accuracy: 0.792391
# Average loss: 0.282132, Train accuracy: 0.884605, Val accuracy: 0.847826
# Average loss: 0.214804, Train accuracy: 0.913386, Val accuracy: 0.731522
# Average loss: 0.228847, Train accuracy: 0.910399, Val accuracy: 0.823913
# Average loss: 0.228658, Train accuracy: 0.909585, Val accuracy: 0.901087
# Average loss: 0.195515, Train accuracy: 0.926419, Val accuracy: 0.880435
# Average loss: 0.179828, Train accuracy: 0.927776, Val accuracy: 0.848913
# Average loss: 0.173809, Train accuracy: 0.932935, Val accuracy: 0.883696
# Average loss: 0.175917, Train accuracy: 0.933750, Val accuracy: 0.833696
# Average loss: 0.146624, Train accuracy: 0.941895, Val accuracy: 0.702174
# Average loss: 0.122462, Train accuracy: 0.953027, Val accuracy: 0.928261
# Average loss: 0.074076, Train accuracy: 0.973663, Val accuracy: 0.929348
# Average loss: 0.064553, Train accuracy: 0.977193, Val accuracy: 0.919565
# Average loss: 0.056538, Train accuracy: 0.977736, Val accuracy: 0.926087
# Average loss: 0.050686, Train accuracy: 0.983980, Val accuracy: 0.931522
# Average loss: 0.050918, Train accuracy: 0.982894, Val accuracy: 0.914130
# Average loss: 0.038704, Train accuracy: 0.985338, Val accuracy: 0.918478
# Average loss: 0.046407, Train accuracy: 0.982623, Val accuracy: 0.926087
# Average loss: 0.033613, Train accuracy: 0.986967, Val accuracy: 0.936957
# Average loss: 0.038994, Train accuracy: 0.984523, Val accuracy: 0.942391
# Average loss: 0.028088, Train accuracy: 0.990225, Val accuracy: 0.934783
# Average loss: 0.029495, Train accuracy: 0.991040, Val accuracy: 0.938043
# Average loss: 0.018278, Train accuracy: 0.994841, Val accuracy: 0.936957
# Average loss: 0.023154, Train accuracy: 0.991583, Val accuracy: 0.936957
# Average loss: 0.016010, Train accuracy: 0.995384, Val accuracy: 0.944565
# Average loss: 0.015333, Train accuracy: 0.994841, Val accuracy: 0.935870
# Average loss: 0.020858, Train accuracy: 0.994027, Val accuracy: 0.939130
# Average loss: 0.011915, Train accuracy: 0.996199, Val accuracy: 0.932609
# Average loss: 0.014089, Train accuracy: 0.995927, Val accuracy: 0.936957
# Average loss: 0.012686, Train accuracy: 0.995927, Val accuracy: 0.938043
# F1: 0.903, P: 0.906, R: 0.900
# (0.001, 1e-07, 0.1)
# Average loss: 0.422887, Train accuracy: 0.830844, Val accuracy: 0.839130
# Average loss: 0.278519, Train accuracy: 0.881075, Val accuracy: 0.766304
# Average loss: 0.230302, Train accuracy: 0.902525, Val accuracy: 0.884783
# Average loss: 0.215234, Train accuracy: 0.909856, Val accuracy: 0.853261
# Average loss: 0.232024, Train accuracy: 0.906326, Val accuracy: 0.841304
# Average loss: 0.197592, Train accuracy: 0.919631, Val accuracy: 0.892391
# Average loss: 0.185839, Train accuracy: 0.931578, Val accuracy: 0.860870
# Average loss: 0.186441, Train accuracy: 0.923704, Val accuracy: 0.882609
# Average loss: 0.179356, Train accuracy: 0.926147, Val accuracy: 0.898913
# Average loss: 0.157561, Train accuracy: 0.936736, Val accuracy: 0.825000
# Average loss: 0.119970, Train accuracy: 0.956557, Val accuracy: 0.927174
# Average loss: 0.082920, Train accuracy: 0.969318, Val accuracy: 0.938043
# Average loss: 0.077964, Train accuracy: 0.969862, Val accuracy: 0.941304
# Average loss: 0.064962, Train accuracy: 0.977736, Val accuracy: 0.941304
# Average loss: 0.062598, Train accuracy: 0.979365, Val accuracy: 0.936957
# Average loss: 0.049265, Train accuracy: 0.980451, Val accuracy: 0.939130
# Average loss: 0.051229, Train accuracy: 0.980179, Val accuracy: 0.941304
# Average loss: 0.049167, Train accuracy: 0.983709, Val accuracy: 0.939130
# Average loss: 0.037411, Train accuracy: 0.986696, Val accuracy: 0.930435
# Average loss: 0.041381, Train accuracy: 0.985338, Val accuracy: 0.936957
# Average loss: 0.029685, Train accuracy: 0.990497, Val accuracy: 0.941304
# Average loss: 0.030531, Train accuracy: 0.990497, Val accuracy: 0.941304
# Average loss: 0.030696, Train accuracy: 0.989682, Val accuracy: 0.935870
# Average loss: 0.033476, Train accuracy: 0.988868, Val accuracy: 0.934783
# Average loss: 0.026719, Train accuracy: 0.991311, Val accuracy: 0.948913
# Average loss: 0.026868, Train accuracy: 0.990225, Val accuracy: 0.939130
# Average loss: 0.027982, Train accuracy: 0.992126, Val accuracy: 0.935870
# Average loss: 0.030971, Train accuracy: 0.991583, Val accuracy: 0.936957
# Average loss: 0.023111, Train accuracy: 0.994027, Val accuracy: 0.934783
# Average loss: 0.023845, Train accuracy: 0.992669, Val accuracy: 0.941304
# F1: 0.915, P: 0.930, R: 0.900
# (0.001, 1e-09, 0.5)
# Average loss: 0.374596, Train accuracy: 0.843606, Val accuracy: 0.861957
# Average loss: 0.275894, Train accuracy: 0.886506, Val accuracy: 0.700000
# Average loss: 0.246211, Train accuracy: 0.901982, Val accuracy: 0.843478
# Average loss: 0.232172, Train accuracy: 0.907141, Val accuracy: 0.825000
# Average loss: 0.207552, Train accuracy: 0.915286, Val accuracy: 0.888043
# Average loss: 0.214071, Train accuracy: 0.921803, Val accuracy: 0.858696
# Average loss: 0.186762, Train accuracy: 0.923704, Val accuracy: 0.881522
# Average loss: 0.199797, Train accuracy: 0.921260, Val accuracy: 0.884783
# Average loss: 0.179983, Train accuracy: 0.927505, Val accuracy: 0.893478
# Average loss: 0.162506, Train accuracy: 0.936736, Val accuracy: 0.875000
# Average loss: 0.119928, Train accuracy: 0.955200, Val accuracy: 0.922826
# Average loss: 0.104816, Train accuracy: 0.959815, Val accuracy: 0.896739
# Average loss: 0.087647, Train accuracy: 0.968232, Val accuracy: 0.921739
# Average loss: 0.088730, Train accuracy: 0.965246, Val accuracy: 0.920652
# Average loss: 0.082594, Train accuracy: 0.969318, Val accuracy: 0.917391
# Average loss: 0.080345, Train accuracy: 0.970405, Val accuracy: 0.877174
# Average loss: 0.075271, Train accuracy: 0.972577, Val accuracy: 0.917391
# Average loss: 0.066064, Train accuracy: 0.975563, Val accuracy: 0.904348
# Average loss: 0.083869, Train accuracy: 0.970133, Val accuracy: 0.910870
# Average loss: 0.069412, Train accuracy: 0.972848, Val accuracy: 0.919565
# Average loss: 0.051247, Train accuracy: 0.981808, Val accuracy: 0.925000
# Average loss: 0.034264, Train accuracy: 0.987782, Val accuracy: 0.927174
# Average loss: 0.044439, Train accuracy: 0.986696, Val accuracy: 0.930435
# Average loss: 0.039467, Train accuracy: 0.985881, Val accuracy: 0.938043
# Average loss: 0.027222, Train accuracy: 0.988868, Val accuracy: 0.935870
# Average loss: 0.033071, Train accuracy: 0.986424, Val accuracy: 0.931522
# Average loss: 0.026231, Train accuracy: 0.991311, Val accuracy: 0.931522
# Average loss: 0.018665, Train accuracy: 0.994027, Val accuracy: 0.934783
# Average loss: 0.032956, Train accuracy: 0.988596, Val accuracy: 0.932609
# Average loss: 0.023779, Train accuracy: 0.992126, Val accuracy: 0.919565
# F1: 0.911, P: 0.887, R: 0.936
# (0.001, 1e-09, 0.2)
# Average loss: 0.429384, Train accuracy: 0.829758, Val accuracy: 0.822826
# Average loss: 0.293623, Train accuracy: 0.880532, Val accuracy: 0.871739
# Average loss: 0.246168, Train accuracy: 0.900896, Val accuracy: 0.868478
# Average loss: 0.239631, Train accuracy: 0.904154, Val accuracy: 0.904348
# Average loss: 0.216884, Train accuracy: 0.913657, Val accuracy: 0.863043
# Average loss: 0.210169, Train accuracy: 0.917459, Val accuracy: 0.785870
# Average loss: 0.187540, Train accuracy: 0.923704, Val accuracy: 0.897826
# Average loss: 0.185677, Train accuracy: 0.924790, Val accuracy: 0.857609
# Average loss: 0.192829, Train accuracy: 0.922889, Val accuracy: 0.903261
# Average loss: 0.176880, Train accuracy: 0.928319, Val accuracy: 0.861957
# Average loss: 0.136656, Train accuracy: 0.947869, Val accuracy: 0.923913
# Average loss: 0.088387, Train accuracy: 0.968232, Val accuracy: 0.939130
# Average loss: 0.076702, Train accuracy: 0.972305, Val accuracy: 0.936957
# Average loss: 0.064755, Train accuracy: 0.976649, Val accuracy: 0.925000
# Average loss: 0.065315, Train accuracy: 0.977464, Val accuracy: 0.918478
# Average loss: 0.068481, Train accuracy: 0.978550, Val accuracy: 0.928261
# Average loss: 0.043019, Train accuracy: 0.985067, Val accuracy: 0.934783
# Average loss: 0.041083, Train accuracy: 0.986696, Val accuracy: 0.935870
# Average loss: 0.035610, Train accuracy: 0.989139, Val accuracy: 0.935870
# Average loss: 0.036742, Train accuracy: 0.985881, Val accuracy: 0.929348
# Average loss: 0.036253, Train accuracy: 0.987782, Val accuracy: 0.936957
# Average loss: 0.024056, Train accuracy: 0.993212, Val accuracy: 0.941304
# Average loss: 0.020957, Train accuracy: 0.993212, Val accuracy: 0.927174
# Average loss: 0.021736, Train accuracy: 0.992941, Val accuracy: 0.921739
# Average loss: 0.021623, Train accuracy: 0.992669, Val accuracy: 0.939130
# Average loss: 0.018716, Train accuracy: 0.993484, Val accuracy: 0.939130
# Average loss: 0.014176, Train accuracy: 0.995384, Val accuracy: 0.932609
# Average loss: 0.015042, Train accuracy: 0.996199, Val accuracy: 0.934783
# Average loss: 0.016979, Train accuracy: 0.995384, Val accuracy: 0.946739
# Average loss: 0.015247, Train accuracy: 0.995384, Val accuracy: 0.938043
# F1: 0.913, P: 0.919, R: 0.907
# (0.001, 1e-09, 0.1)
# Average loss: 0.414390, Train accuracy: 0.824328, Val accuracy: 0.832609
# Average loss: 0.287326, Train accuracy: 0.884605, Val accuracy: 0.856522
# Average loss: 0.243294, Train accuracy: 0.903611, Val accuracy: 0.820652
# Average loss: 0.226689, Train accuracy: 0.907955, Val accuracy: 0.763043
# Average loss: 0.221831, Train accuracy: 0.909313, Val accuracy: 0.882609
# Average loss: 0.197999, Train accuracy: 0.922617, Val accuracy: 0.878261
# Average loss: 0.213001, Train accuracy: 0.912300, Val accuracy: 0.848913
# Average loss: 0.177854, Train accuracy: 0.930491, Val accuracy: 0.876087
# Average loss: 0.182150, Train accuracy: 0.927776, Val accuracy: 0.804348
# Average loss: 0.180955, Train accuracy: 0.934836, Val accuracy: 0.865217
# Average loss: 0.121828, Train accuracy: 0.954385, Val accuracy: 0.917391
# Average loss: 0.093523, Train accuracy: 0.966875, Val accuracy: 0.922826
# Average loss: 0.077892, Train accuracy: 0.971491, Val accuracy: 0.923913
# Average loss: 0.066414, Train accuracy: 0.976106, Val accuracy: 0.920652
# Average loss: 0.065173, Train accuracy: 0.973934, Val accuracy: 0.923913
# Average loss: 0.052042, Train accuracy: 0.980994, Val accuracy: 0.917391
# Average loss: 0.048343, Train accuracy: 0.982080, Val accuracy: 0.923913
# Average loss: 0.045902, Train accuracy: 0.983980, Val accuracy: 0.934783
# Average loss: 0.044680, Train accuracy: 0.983980, Val accuracy: 0.920652
# Average loss: 0.036402, Train accuracy: 0.986967, Val accuracy: 0.938043
# Average loss: 0.038101, Train accuracy: 0.988596, Val accuracy: 0.934783
# Average loss: 0.032152, Train accuracy: 0.988868, Val accuracy: 0.930435
# Average loss: 0.031980, Train accuracy: 0.988325, Val accuracy: 0.925000
# Average loss: 0.027326, Train accuracy: 0.991583, Val accuracy: 0.929348
# Average loss: 0.029104, Train accuracy: 0.991311, Val accuracy: 0.935870
# Average loss: 0.024920, Train accuracy: 0.992398, Val accuracy: 0.927174
# Average loss: 0.034960, Train accuracy: 0.989139, Val accuracy: 0.930435
# Average loss: 0.027016, Train accuracy: 0.990768, Val accuracy: 0.939130
# Average loss: 0.031720, Train accuracy: 0.988325, Val accuracy: 0.929348
# Average loss: 0.032683, Train accuracy: 0.989682, Val accuracy: 0.927174
# F1: 0.891, P: 0.891, R: 0.891
# (0.0001, 1e-05, 0.5)
# Average loss: 0.351258, Train accuracy: 0.866956, Val accuracy: 0.929348
# Average loss: 0.139446, Train accuracy: 0.949769, Val accuracy: 0.933696
# Average loss: 0.091420, Train accuracy: 0.966603, Val accuracy: 0.944565
# Average loss: 0.062601, Train accuracy: 0.977736, Val accuracy: 0.935870
# Average loss: 0.054810, Train accuracy: 0.984252, Val accuracy: 0.939130
# Average loss: 0.047892, Train accuracy: 0.983709, Val accuracy: 0.944565
# Average loss: 0.046378, Train accuracy: 0.982894, Val accuracy: 0.940217
# Average loss: 0.048098, Train accuracy: 0.985067, Val accuracy: 0.943478
# Average loss: 0.037375, Train accuracy: 0.986967, Val accuracy: 0.951087
# Average loss: 0.039066, Train accuracy: 0.987239, Val accuracy: 0.940217
# Average loss: 0.024785, Train accuracy: 0.992126, Val accuracy: 0.945652
# Average loss: 0.017554, Train accuracy: 0.994841, Val accuracy: 0.948913
# Average loss: 0.014150, Train accuracy: 0.996199, Val accuracy: 0.951087
# Average loss: 0.014111, Train accuracy: 0.997013, Val accuracy: 0.935870
# Average loss: 0.014028, Train accuracy: 0.995927, Val accuracy: 0.955435
# Average loss: 0.011454, Train accuracy: 0.997285, Val accuracy: 0.950000
# Average loss: 0.012954, Train accuracy: 0.995113, Val accuracy: 0.947826
# Average loss: 0.006695, Train accuracy: 0.998642, Val accuracy: 0.954348
# Average loss: 0.011329, Train accuracy: 0.995656, Val accuracy: 0.953261
# Average loss: 0.006796, Train accuracy: 0.998371, Val accuracy: 0.954348
# Average loss: 0.005529, Train accuracy: 0.998642, Val accuracy: 0.953261
# Average loss: 0.006703, Train accuracy: 0.998099, Val accuracy: 0.956522
# Average loss: 0.004011, Train accuracy: 0.998642, Val accuracy: 0.952174
# Average loss: 0.003181, Train accuracy: 0.999457, Val accuracy: 0.960870
# Average loss: 0.005789, Train accuracy: 0.997556, Val accuracy: 0.959783
# Average loss: 0.003319, Train accuracy: 1.000000, Val accuracy: 0.951087
# Average loss: 0.003182, Train accuracy: 0.999457, Val accuracy: 0.959783
# Average loss: 0.003327, Train accuracy: 0.999728, Val accuracy: 0.957609
# Average loss: 0.002753, Train accuracy: 0.999728, Val accuracy: 0.947826
# Average loss: 0.005169, Train accuracy: 0.998914, Val accuracy: 0.948913
# F1: 0.930, P: 0.965, R: 0.897
# (0.0001, 1e-05, 0.2)
# Average loss: 0.224628, Train accuracy: 0.907684, Val accuracy: 0.928261
# Average loss: 0.127372, Train accuracy: 0.951670, Val accuracy: 0.929348
# Average loss: 0.096903, Train accuracy: 0.964703, Val accuracy: 0.942391
# Average loss: 0.069047, Train accuracy: 0.975563, Val accuracy: 0.933696
# Average loss: 0.056876, Train accuracy: 0.981265, Val accuracy: 0.934783
# Average loss: 0.057506, Train accuracy: 0.980994, Val accuracy: 0.954348
# Average loss: 0.043268, Train accuracy: 0.985067, Val accuracy: 0.943478
# Average loss: 0.035427, Train accuracy: 0.985881, Val accuracy: 0.952174
# Average loss: 0.019270, Train accuracy: 0.993484, Val accuracy: 0.944565
# Average loss: 0.019368, Train accuracy: 0.992126, Val accuracy: 0.957609
# Average loss: 0.015404, Train accuracy: 0.995113, Val accuracy: 0.955435
# Average loss: 0.011687, Train accuracy: 0.996470, Val accuracy: 0.955435
# Average loss: 0.009661, Train accuracy: 0.997556, Val accuracy: 0.964130
# Average loss: 0.010158, Train accuracy: 0.997285, Val accuracy: 0.959783
# Average loss: 0.010132, Train accuracy: 0.997013, Val accuracy: 0.959783
# Average loss: 0.006638, Train accuracy: 0.998099, Val accuracy: 0.955435
# Average loss: 0.004321, Train accuracy: 0.999728, Val accuracy: 0.960870
# Average loss: 0.006586, Train accuracy: 0.998371, Val accuracy: 0.958696
# Average loss: 0.005848, Train accuracy: 0.998914, Val accuracy: 0.959783
# Average loss: 0.006243, Train accuracy: 0.997828, Val accuracy: 0.958696
# Average loss: 0.006554, Train accuracy: 0.998642, Val accuracy: 0.953261
# Average loss: 0.005417, Train accuracy: 0.998914, Val accuracy: 0.952174
# Average loss: 0.004430, Train accuracy: 0.999185, Val accuracy: 0.956522
# Average loss: 0.003661, Train accuracy: 1.000000, Val accuracy: 0.954348
# Average loss: 0.004334, Train accuracy: 0.998914, Val accuracy: 0.961957
# Average loss: 0.004463, Train accuracy: 0.999457, Val accuracy: 0.963043
# Average loss: 0.002964, Train accuracy: 1.000000, Val accuracy: 0.953261
# Average loss: 0.002904, Train accuracy: 1.000000, Val accuracy: 0.956522
# Average loss: 0.004459, Train accuracy: 0.999185, Val accuracy: 0.954348
# Average loss: 0.003951, Train accuracy: 0.999185, Val accuracy: 0.954348
# F1: 0.944, P: 0.960, R: 0.929
# (0.0001, 1e-05, 0.1)
# Average loss: 0.218398, Train accuracy: 0.909313, Val accuracy: 0.931522
# Average loss: 0.132152, Train accuracy: 0.950312, Val accuracy: 0.946739
# Average loss: 0.090254, Train accuracy: 0.965789, Val accuracy: 0.954348
# Average loss: 0.069777, Train accuracy: 0.974477, Val accuracy: 0.947826
# Average loss: 0.053740, Train accuracy: 0.979636, Val accuracy: 0.935870
# Average loss: 0.046257, Train accuracy: 0.986153, Val accuracy: 0.947826
# Average loss: 0.039233, Train accuracy: 0.984523, Val accuracy: 0.952174
# Average loss: 0.034400, Train accuracy: 0.989139, Val accuracy: 0.942391
# Average loss: 0.022992, Train accuracy: 0.993755, Val accuracy: 0.951087
# Average loss: 0.024000, Train accuracy: 0.992941, Val accuracy: 0.943478
# Average loss: 0.019375, Train accuracy: 0.994298, Val accuracy: 0.944565
# Average loss: 0.017866, Train accuracy: 0.994570, Val accuracy: 0.954348
# Average loss: 0.012237, Train accuracy: 0.995656, Val accuracy: 0.946739
# Average loss: 0.008797, Train accuracy: 0.998914, Val accuracy: 0.951087
# Average loss: 0.010353, Train accuracy: 0.997285, Val accuracy: 0.945652
# Average loss: 0.010877, Train accuracy: 0.996470, Val accuracy: 0.947826
# Average loss: 0.009201, Train accuracy: 0.997556, Val accuracy: 0.952174
# Average loss: 0.006032, Train accuracy: 0.998914, Val accuracy: 0.952174
# Average loss: 0.007368, Train accuracy: 0.997828, Val accuracy: 0.945652
# Average loss: 0.007858, Train accuracy: 0.997556, Val accuracy: 0.954348
# Average loss: 0.007443, Train accuracy: 0.998642, Val accuracy: 0.951087
# Average loss: 0.007762, Train accuracy: 0.998099, Val accuracy: 0.951087
# Average loss: 0.008555, Train accuracy: 0.997828, Val accuracy: 0.947826
# Average loss: 0.008131, Train accuracy: 0.998371, Val accuracy: 0.952174
# Average loss: 0.005788, Train accuracy: 0.998642, Val accuracy: 0.957609
# Average loss: 0.008522, Train accuracy: 0.997013, Val accuracy: 0.950000
# Average loss: 0.005469, Train accuracy: 0.999457, Val accuracy: 0.952174
# Average loss: 0.005404, Train accuracy: 0.999185, Val accuracy: 0.956522
# Average loss: 0.006971, Train accuracy: 0.998914, Val accuracy: 0.950000
# Average loss: 0.006257, Train accuracy: 0.998642, Val accuracy: 0.954348
# F1: 0.933, P: 0.953, R: 0.913
# (0.0001, 1e-07, 0.5)
# Average loss: 0.237181, Train accuracy: 0.898452, Val accuracy: 0.934783
# Average loss: 0.124324, Train accuracy: 0.950584, Val accuracy: 0.940217
# Average loss: 0.085370, Train accuracy: 0.969862, Val accuracy: 0.944565
# Average loss: 0.071889, Train accuracy: 0.976649, Val accuracy: 0.932609
# Average loss: 0.057098, Train accuracy: 0.980179, Val accuracy: 0.936957
# Average loss: 0.050186, Train accuracy: 0.982894, Val accuracy: 0.944565
# Average loss: 0.048319, Train accuracy: 0.983437, Val accuracy: 0.946739
# Average loss: 0.028849, Train accuracy: 0.991854, Val accuracy: 0.948913
# Average loss: 0.030911, Train accuracy: 0.988596, Val accuracy: 0.933696
# Average loss: 0.030583, Train accuracy: 0.991040, Val accuracy: 0.938043
# Average loss: 0.017682, Train accuracy: 0.993212, Val accuracy: 0.943478
# Average loss: 0.013515, Train accuracy: 0.996470, Val accuracy: 0.953261
# Average loss: 0.009809, Train accuracy: 0.997285, Val accuracy: 0.953261
# Average loss: 0.012376, Train accuracy: 0.997013, Val accuracy: 0.948913
# Average loss: 0.005991, Train accuracy: 0.998914, Val accuracy: 0.952174
# Average loss: 0.007808, Train accuracy: 0.998099, Val accuracy: 0.944565
# Average loss: 0.005836, Train accuracy: 0.998371, Val accuracy: 0.953261
# Average loss: 0.008417, Train accuracy: 0.997285, Val accuracy: 0.954348
# Average loss: 0.005017, Train accuracy: 0.998914, Val accuracy: 0.945652
# Average loss: 0.004703, Train accuracy: 0.999185, Val accuracy: 0.951087
# Average loss: 0.003955, Train accuracy: 0.999457, Val accuracy: 0.957609
# Average loss: 0.004861, Train accuracy: 0.998642, Val accuracy: 0.954348
# Average loss: 0.004542, Train accuracy: 0.998914, Val accuracy: 0.952174
# Average loss: 0.003299, Train accuracy: 0.999185, Val accuracy: 0.948913
# Average loss: 0.004962, Train accuracy: 0.998914, Val accuracy: 0.954348
# Average loss: 0.004630, Train accuracy: 0.998914, Val accuracy: 0.953261
# Average loss: 0.002123, Train accuracy: 1.000000, Val accuracy: 0.956522
# Average loss: 0.002798, Train accuracy: 0.999185, Val accuracy: 0.955435
# Average loss: 0.003920, Train accuracy: 0.998914, Val accuracy: 0.950000
# Average loss: 0.003998, Train accuracy: 0.999185, Val accuracy: 0.951087
# F1: 0.939, P: 0.936, R: 0.942
# (0.0001, 1e-07, 0.2)
# Average loss: 0.251183, Train accuracy: 0.896009, Val accuracy: 0.933696
# Average loss: 0.123157, Train accuracy: 0.951941, Val accuracy: 0.944565
# Average loss: 0.094046, Train accuracy: 0.969318, Val accuracy: 0.897826
# Average loss: 0.080238, Train accuracy: 0.972577, Val accuracy: 0.943478
# Average loss: 0.057996, Train accuracy: 0.980179, Val accuracy: 0.948913
# Average loss: 0.042896, Train accuracy: 0.985610, Val accuracy: 0.953261
# Average loss: 0.035928, Train accuracy: 0.986696, Val accuracy: 0.951087
# Average loss: 0.040798, Train accuracy: 0.984523, Val accuracy: 0.936957
# Average loss: 0.036696, Train accuracy: 0.987782, Val accuracy: 0.941304
# Average loss: 0.034760, Train accuracy: 0.986967, Val accuracy: 0.944565
# Average loss: 0.015803, Train accuracy: 0.996199, Val accuracy: 0.951087
# Average loss: 0.018497, Train accuracy: 0.993484, Val accuracy: 0.946739
# Average loss: 0.011547, Train accuracy: 0.996199, Val accuracy: 0.957609
# Average loss: 0.009596, Train accuracy: 0.998371, Val accuracy: 0.957609
# Average loss: 0.011328, Train accuracy: 0.996199, Val accuracy: 0.954348
# Average loss: 0.010062, Train accuracy: 0.997285, Val accuracy: 0.952174
# Average loss: 0.006842, Train accuracy: 0.998099, Val accuracy: 0.953261
# Average loss: 0.007795, Train accuracy: 0.998371, Val accuracy: 0.961957
# Average loss: 0.008453, Train accuracy: 0.998371, Val accuracy: 0.954348
# Average loss: 0.006564, Train accuracy: 0.998642, Val accuracy: 0.950000
# Average loss: 0.007037, Train accuracy: 0.998371, Val accuracy: 0.950000
# Average loss: 0.005931, Train accuracy: 0.998371, Val accuracy: 0.960870
# Average loss: 0.007511, Train accuracy: 0.998914, Val accuracy: 0.952174
# Average loss: 0.006617, Train accuracy: 0.998914, Val accuracy: 0.952174
# Average loss: 0.004958, Train accuracy: 0.998914, Val accuracy: 0.955435
# Average loss: 0.006339, Train accuracy: 0.998371, Val accuracy: 0.958696
# Average loss: 0.004476, Train accuracy: 0.999185, Val accuracy: 0.955435
# Average loss: 0.004417, Train accuracy: 0.998914, Val accuracy: 0.958696
# Average loss: 0.004176, Train accuracy: 0.999457, Val accuracy: 0.954348
# Average loss: 0.006605, Train accuracy: 0.997828, Val accuracy: 0.954348
# F1: 0.940, P: 0.948, R: 0.932
# (0.0001, 1e-07, 0.1)
# Average loss: 0.226826, Train accuracy: 0.909042, Val accuracy: 0.933696
# Average loss: 0.121642, Train accuracy: 0.951398, Val accuracy: 0.934783
# Average loss: 0.089221, Train accuracy: 0.970676, Val accuracy: 0.944565
# Average loss: 0.060125, Train accuracy: 0.980994, Val accuracy: 0.932609
# Average loss: 0.062008, Train accuracy: 0.977464, Val accuracy: 0.936957
# Average loss: 0.052614, Train accuracy: 0.981808, Val accuracy: 0.944565
# Average loss: 0.042226, Train accuracy: 0.984795, Val accuracy: 0.947826
# Average loss: 0.034343, Train accuracy: 0.988325, Val accuracy: 0.958696
# Average loss: 0.038468, Train accuracy: 0.986153, Val accuracy: 0.916304
# Average loss: 0.037106, Train accuracy: 0.986696, Val accuracy: 0.941304
# Average loss: 0.024244, Train accuracy: 0.992941, Val accuracy: 0.950000
# Average loss: 0.017489, Train accuracy: 0.994298, Val accuracy: 0.946739
# Average loss: 0.014616, Train accuracy: 0.994841, Val accuracy: 0.948913
# Average loss: 0.013772, Train accuracy: 0.995113, Val accuracy: 0.955435
# Average loss: 0.011105, Train accuracy: 0.997013, Val accuracy: 0.955435
# Average loss: 0.009433, Train accuracy: 0.997556, Val accuracy: 0.959783
# Average loss: 0.008448, Train accuracy: 0.998371, Val accuracy: 0.948913
# Average loss: 0.006032, Train accuracy: 0.999457, Val accuracy: 0.965217
# Average loss: 0.008505, Train accuracy: 0.998914, Val accuracy: 0.953261
# Average loss: 0.009558, Train accuracy: 0.998099, Val accuracy: 0.948913
# Average loss: 0.006139, Train accuracy: 0.999457, Val accuracy: 0.952174
# Average loss: 0.008571, Train accuracy: 0.998371, Val accuracy: 0.958696
# Average loss: 0.007202, Train accuracy: 0.998914, Val accuracy: 0.961957
# Average loss: 0.006587, Train accuracy: 0.998371, Val accuracy: 0.954348
# Average loss: 0.007437, Train accuracy: 0.998371, Val accuracy: 0.950000
# Average loss: 0.006533, Train accuracy: 0.998371, Val accuracy: 0.952174
# Average loss: 0.006994, Train accuracy: 0.998914, Val accuracy: 0.958696
# Average loss: 0.005467, Train accuracy: 0.999185, Val accuracy: 0.956522
# Average loss: 0.006541, Train accuracy: 0.998099, Val accuracy: 0.957609
# Average loss: 0.005491, Train accuracy: 0.999457, Val accuracy: 0.950000
# F1: 0.930, P: 0.944, R: 0.916
# (0.0001, 1e-09, 0.5)
# Average loss: 0.226211, Train accuracy: 0.910399, Val accuracy: 0.935870
# Average loss: 0.124772, Train accuracy: 0.949498, Val accuracy: 0.940217
# Average loss: 0.088003, Train accuracy: 0.965789, Val accuracy: 0.945652
# Average loss: 0.067219, Train accuracy: 0.976921, Val accuracy: 0.941304
# Average loss: 0.053624, Train accuracy: 0.980722, Val accuracy: 0.955435
# Average loss: 0.048263, Train accuracy: 0.982623, Val accuracy: 0.929348
# Average loss: 0.045297, Train accuracy: 0.986153, Val accuracy: 0.939130
# Average loss: 0.043431, Train accuracy: 0.986153, Val accuracy: 0.943478
# Average loss: 0.033808, Train accuracy: 0.987510, Val accuracy: 0.942391
# Average loss: 0.030185, Train accuracy: 0.991040, Val accuracy: 0.944565
# Average loss: 0.022556, Train accuracy: 0.993484, Val accuracy: 0.951087
# Average loss: 0.009567, Train accuracy: 0.998371, Val accuracy: 0.955435
# Average loss: 0.009646, Train accuracy: 0.997285, Val accuracy: 0.953261
# Average loss: 0.013182, Train accuracy: 0.995656, Val accuracy: 0.952174
# Average loss: 0.007067, Train accuracy: 0.998642, Val accuracy: 0.954348
# Average loss: 0.008287, Train accuracy: 0.997556, Val accuracy: 0.944565
# Average loss: 0.007552, Train accuracy: 0.997556, Val accuracy: 0.960870
# Average loss: 0.006853, Train accuracy: 0.999185, Val accuracy: 0.958696
# Average loss: 0.003758, Train accuracy: 0.999457, Val accuracy: 0.954348
# Average loss: 0.004300, Train accuracy: 0.998914, Val accuracy: 0.956522
# Average loss: 0.003362, Train accuracy: 0.999457, Val accuracy: 0.952174
# Average loss: 0.004641, Train accuracy: 0.998371, Val accuracy: 0.955435
# Average loss: 0.003699, Train accuracy: 0.998642, Val accuracy: 0.950000
# Average loss: 0.004210, Train accuracy: 0.998642, Val accuracy: 0.952174
# Average loss: 0.004091, Train accuracy: 0.998914, Val accuracy: 0.945652
# Average loss: 0.002726, Train accuracy: 0.999185, Val accuracy: 0.953261
# Average loss: 0.003582, Train accuracy: 0.998642, Val accuracy: 0.954348
# Average loss: 0.002008, Train accuracy: 0.999728, Val accuracy: 0.957609
# Average loss: 0.003092, Train accuracy: 0.999185, Val accuracy: 0.959783
# Average loss: 0.003653, Train accuracy: 0.998642, Val accuracy: 0.955435
# F1: 0.941, P: 0.934, R: 0.949
# (0.0001, 1e-09, 0.2)
# Average loss: 0.277201, Train accuracy: 0.884333, Val accuracy: 0.923913
# Average loss: 0.125183, Train accuracy: 0.952756, Val accuracy: 0.945652
# Average loss: 0.095930, Train accuracy: 0.966332, Val accuracy: 0.943478
# Average loss: 0.085304, Train accuracy: 0.966603, Val accuracy: 0.950000
# Average loss: 0.064817, Train accuracy: 0.978007, Val accuracy: 0.946739
# Average loss: 0.047590, Train accuracy: 0.982351, Val accuracy: 0.946739
# Average loss: 0.051386, Train accuracy: 0.980179, Val accuracy: 0.945652
# Average loss: 0.036431, Train accuracy: 0.987782, Val accuracy: 0.953261
# Average loss: 0.029152, Train accuracy: 0.989682, Val accuracy: 0.940217
# Average loss: 0.022017, Train accuracy: 0.993755, Val accuracy: 0.954348
# Average loss: 0.014022, Train accuracy: 0.996470, Val accuracy: 0.952174
# Average loss: 0.015961, Train accuracy: 0.995656, Val accuracy: 0.958696
# Average loss: 0.010312, Train accuracy: 0.996742, Val accuracy: 0.957609
# Average loss: 0.012520, Train accuracy: 0.996470, Val accuracy: 0.947826
# Average loss: 0.009365, Train accuracy: 0.998099, Val accuracy: 0.952174
# Average loss: 0.006287, Train accuracy: 0.998642, Val accuracy: 0.946739
# Average loss: 0.006108, Train accuracy: 0.998914, Val accuracy: 0.952174
# Average loss: 0.005675, Train accuracy: 0.999185, Val accuracy: 0.953261
# Average loss: 0.006595, Train accuracy: 0.998914, Val accuracy: 0.943478
# Average loss: 0.005691, Train accuracy: 0.999185, Val accuracy: 0.948913
# Average loss: 0.005386, Train accuracy: 0.998914, Val accuracy: 0.951087
# Average loss: 0.005628, Train accuracy: 0.999185, Val accuracy: 0.954348
# Average loss: 0.004794, Train accuracy: 0.999185, Val accuracy: 0.956522
# Average loss: 0.004770, Train accuracy: 0.999185, Val accuracy: 0.955435
# Average loss: 0.005147, Train accuracy: 0.998642, Val accuracy: 0.952174
# Average loss: 0.004562, Train accuracy: 0.999185, Val accuracy: 0.954348
# Average loss: 0.003576, Train accuracy: 0.999728, Val accuracy: 0.954348
# Average loss: 0.003810, Train accuracy: 0.999457, Val accuracy: 0.961957
# Average loss: 0.006217, Train accuracy: 0.998099, Val accuracy: 0.950000
# Average loss: 0.004133, Train accuracy: 0.999457, Val accuracy: 0.951087
# F1: 0.941, P: 0.957, R: 0.926
# (0.0001, 1e-09, 0.1)
# Average loss: 0.237114, Train accuracy: 0.898724, Val accuracy: 0.926087
# Average loss: 0.134563, Train accuracy: 0.951127, Val accuracy: 0.939130
# Average loss: 0.084975, Train accuracy: 0.971762, Val accuracy: 0.941304
# Average loss: 0.068090, Train accuracy: 0.977193, Val accuracy: 0.933696
# Average loss: 0.064907, Train accuracy: 0.978007, Val accuracy: 0.944565
# Average loss: 0.054731, Train accuracy: 0.979093, Val accuracy: 0.941304
# Average loss: 0.042224, Train accuracy: 0.986153, Val accuracy: 0.931522
# Average loss: 0.027613, Train accuracy: 0.991040, Val accuracy: 0.948913
# Average loss: 0.032558, Train accuracy: 0.989682, Val accuracy: 0.943478
# Average loss: 0.021450, Train accuracy: 0.992941, Val accuracy: 0.941304
# Average loss: 0.024065, Train accuracy: 0.990768, Val accuracy: 0.944565
# Average loss: 0.013754, Train accuracy: 0.996199, Val accuracy: 0.952174
# Average loss: 0.014441, Train accuracy: 0.995113, Val accuracy: 0.950000
# Average loss: 0.012189, Train accuracy: 0.996470, Val accuracy: 0.952174
# Average loss: 0.012950, Train accuracy: 0.996199, Val accuracy: 0.953261
# Average loss: 0.009133, Train accuracy: 0.997828, Val accuracy: 0.952174
# Average loss: 0.012011, Train accuracy: 0.996742, Val accuracy: 0.948913
# Average loss: 0.011592, Train accuracy: 0.997013, Val accuracy: 0.955435
# Average loss: 0.008801, Train accuracy: 0.998099, Val accuracy: 0.946739
# Average loss: 0.004985, Train accuracy: 0.999185, Val accuracy: 0.952174
# Average loss: 0.006941, Train accuracy: 0.998642, Val accuracy: 0.951087
# Average loss: 0.006381, Train accuracy: 0.998371, Val accuracy: 0.960870
# Average loss: 0.006307, Train accuracy: 0.999457, Val accuracy: 0.959783
# Average loss: 0.007260, Train accuracy: 0.998642, Val accuracy: 0.953261
# Average loss: 0.004942, Train accuracy: 0.998914, Val accuracy: 0.956522
# Average loss: 0.007769, Train accuracy: 0.998099, Val accuracy: 0.957609
# Average loss: 0.005732, Train accuracy: 0.998642, Val accuracy: 0.955435
# Average loss: 0.006235, Train accuracy: 0.998642, Val accuracy: 0.958696
# Average loss: 0.004414, Train accuracy: 0.999185, Val accuracy: 0.958696
# Average loss: 0.006500, Train accuracy: 0.998914, Val accuracy: 0.948913
# F1: 0.939, P: 0.942, R: 0.936

# %%
print(f"F1: {best_f1}")
print(f"(lr, reg): {best_hyper_params}\n")
best_loss_history, best_train_history, best_val_history = model_histories
print(f"Loss history: {best_loss_history}\n")
print(f"Train history: {best_train_history}\n")
print(f"Val history: {best_val_history}\n")
# Out:
# F1: 0.9444444444444444
# (lr, reg): (0.0001, 1e-05, 0.2)
#
# Loss history: [0.22462831437587738, 0.1273723840713501, 0.09690263122320175, 0.06904657185077667, 0.05687623843550682, 0.05750557407736778, 0.043268315494060516, 0.03542667627334595, 0.01927027851343155, 0.019368335604667664, 0.015404247678816319, 0.01168675348162651, 0.009661135263741016, 0.01015782542526722, 0.010132291354238987, 0.006638484075665474, 0.004321033135056496, 0.0065863169729709625, 0.005847522988915443, 0.006243470590561628, 0.006554276216775179, 0.005416534841060638, 0.004429909400641918, 0.0036612232215702534, 0.0043343123979866505, 0.004462897777557373, 0.0029639715794473886, 0.002904485911130905, 0.004459106829017401, 0.003951353952288628]
#
# Train history: [0.907683953298941, 0.9516698343741515, 0.9647026880260657, 0.9755633994026609, 0.9812652728753734, 0.9809937550909584, 0.9850665218571817, 0.9858810752104262, 0.9934835731740429, 0.9921259842519685, 0.9951126798805322, 0.9964702688026066, 0.997556339940266, 0.9972848221558512, 0.9970133043714363, 0.9980993755090959, 0.9997284822155851, 0.9983708932935107, 0.9989139288623404, 0.997827857724681, 0.9986424110779256, 0.9989139288623404, 0.9991854466467553, 1.0, 0.9989139288623404, 0.9994569644311703, 1.0, 1.0, 0.9991854466467553, 0.9991854466467553]
#
# Val history: [0.9282608695652174, 0.9293478260869565, 0.9423913043478261, 0.933695652173913, 0.9347826086956522, 0.9543478260869566, 0.9434782608695652, 0.9521739130434783, 0.9445652173913044, 0.9576086956521739, 0.9554347826086956, 0.9554347826086956, 0.9641304347826087, 0.9597826086956521, 0.9597826086956521, 0.9554347826086956, 0.9608695652173913, 0.9586956521739131, 0.9597826086956521, 0.9586956521739131, 0.9532608695652174, 0.9521739130434783, 0.9565217391304348, 0.9543478260869566, 0.9619565217391305, 0.9630434782608696, 0.9532608695652174, 0.9565217391304348, 0.9543478260869566, 0.9543478260869566]

# %%
# Let's check how it performs on validation set!
predictions, ground_truth = evaluate_model(best_model, train_dataset, val_indices)
precision, recall, f1 = binary_classification_metrics(predictions, ground_truth)
print("F1: %4.3f, P: %4.3f, R: %4.3f" % (f1, precision, recall))

# TODO: Visualize training curve for the best model
plt.plot(best_train_history)
plt.plot(best_val_history)
# Out:
# F1: 0.944, P: 0.960, R: 0.929

# %% [markdown]
# ## Визуализируйте ошибки лучшей модели

# %%
# TODO Visualize false positives and false negatives of the best model on the validation set
# TODO: Compute indices of the false positives on the validation set.
# Note those have to be indices of the original dataset
false_positive_indices = [val_idx for i, val_idx in enumerate(val_indices) if (predictions[i] and not ground_truth[i])]
visualize_samples(orig_dataset, false_positive_indices, "False positives")

# TODO: Compute indices of the false negatives on the validation set.
# Note those have to be indices of the original dataset
false_negatives_indices = [val_idx for i, val_idx in enumerate(val_indices) if (not predictions[i] and ground_truth[i])]
visualize_samples(orig_dataset, false_negatives_indices, "False negatives")

# %% [markdown]
# # Необязательное задание с большой звездочкой
#
# Поучавствуйте в Kaggle In-Class Hot Dog Recognition Challenge!
# Это соревнование сделано специально для курса и в нем учавствуют только те, кто проходит курс.
#
# В нем участники соревнуются в качестве натренированных моделей, загружая на сайт предсказания своих моделей на тестовой выборке. Разметка тестовой выборке участникам недоступна.
# Более подробно о правилах соревнования ниже.
#
# Те, кто проходят курс лично, за высокое место в соревновании получат дополнительные баллы.
#
# Вот ссылка на соревнование:
# https://www.kaggle.com/c/hotdogornot

# %%
image_id = []
predictions = []
model.eval()
for x,_,id_img in test_loader:
    # TODO : Напишите код для предсказания меток (1 = есть хотдог, 0 = хотдога нет)
    # Код должен возвратить список из id картинки и метку predictions
    # image id - это название файла картинки, например '10000.jpg'
    x_gpu = x.to(device)

    prediction = model(x_gpu)
    prediction_classes = torch.argmax(prediction, 1).cpu().numpy()
    predictions.extend(prediction_classes)
    image_id.extend(id_img)

# %%
# Так можно создать csv файл, чтобы затем загрузить его на kaggle
# Ожидаемый формат csv-файла:
# image_id,label
# 10000.jpg,1
# 10001.jpg,1
# 10002.jpg,0
# 10003.jpg,1
# 10004.jpg,0

with open('subm.csv', 'w', newline='') as submissionFile:
    writer = csv.writer(submissionFile)
    writer.writerow(['image_id', 'label'])
    writer.writerows(zip(image_id,predictions))

# %%
# А так можно скачать файл с Google Colab
files.download('subm.csv')

# %% [markdown]
# ### Небольшое введение в Kaggle для тех, кто не слышал об этой платформе раньше

# %% [markdown]
# В основе своей Kaggle - это платформа для проведения соревнований по машинному обучению. Появилась она в 2010 и, пожалуй, стала самой популярной и известной из всех существующих площадок по машинному обучению. Надо сказать, что Kaggle - это не только соревнования, но и сообщество людей, увлеченных машинным обучением. А судя по Википедии, в 2017 году отметка зарегистрированных пользователей перевалила за миллион. Есть там и обучающие материалы, возможность задавать вопросы, делиться кодом и идеями - просто мечта.
#
# ### Как проходят соревнования?
# Обычно участники скачивают данные для обучения моделей (train data), чтобы затем делать предсказания на тестовых данных (test data). Обучающая выборка содержит как сами данные, так и правильные метки (значения зависимой переменной), чтобы можно было обучить модель. Но тестовые данные ответа не содержат - и нашей целью является предсказание меток по имеющимся данным. Файл с ответами для каждого наблюдения из тестовой выборки загружается на Kaggle и оценивается в соответствии с выбранной метрикой соревнования, а результат является публичным и показывается в общей таблице (ее называют еще лидербордом - leaderboard) - чтобы появилось желание посоревноваться и создать еще более сильную модель. В "настоящих" соревнованиях, которые проходят на Kaggle, есть и денежное вознаграждение для тех участников, кто занимает первые места на лидерборде. Например, в [этом](https://www.kaggle.com/c/zillow-prize-1#description) соревновании, человек, занявший первое место, получил около 1 000 000 долларов.
#
# Тестовые данные делятся случайным образом в некоторой пропорции. И пока соревнование идет, на лидерборде показываются очки и рейтинг участников только по одной части (Public Leaderboard). А вот когда соревнование заканчивается, то рейтинг участников составляется по второй части тестовых данных (Private Leaderboard). И часто можно видеть, как люди занимавшие первые места на публичной части тестовых данных, оказываются далеко не первыми на закрытой части тестовых данных. Зачем это сделано? Есть несколько причин, но, пожалуй, самой фундаментальной является идея недообучения-переобучения. Всегда возможно, что наша модель настроилась на конкретную выборку, но как она поведет себя на тех данных, которые еще не видела? Разбиение тестовых данных на публичную и скрытую части сделано для того, чтобы отобрать модели, которые имеют большую обобщающую способность. Одним из лозунгов участников соревнований стал "Доверяйте своей локальной кросс-валидации" (Trust your CV!). Есть очень большой соблазн оценивать свою модель по публичной части лидерборда, но лучшей стратегией будет выбирать ту модель, которая дает лучшую метрику на кросс-валидации на обучающей выборке.
#
# В нашем соревновании публичная часть лидерборда составляет 30%, а скрытая 70%. Вы можете делать до двух попыток в день, а оцениваться попытки будут по F1-мере. Удачи и доверяйте своей локальной валидации! В конце соревнования у вас будет возможность выбрать 2 из всех совершенных попыток - лучшая из этих двух и будет засчитана вам на скрытой части тестовых данных.
